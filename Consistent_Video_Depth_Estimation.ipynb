# %% [markdown]
# <a href="https://colab.research.google.com/github/Jasonjk3/AI/blob/master/Consistent_Video_Depth_Estimation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [SIGGRAPH 2020] Consistent Video Depth Estimation
# [Project website](https://github.com/facebookresearch/consistent_depth)

# %% [markdown]
# ## Download Code

# %%
# %cd /content/
# !git clone https://github.com/facebookresearch/consistent_depth.git
# %cd consistent_depth
# !git submodule update --init --recursive
# Out:
# /content
# Cloning into 'consistent_depth'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 57 (delta 0), reused 52 (delta 0), pack-reused 5
# Unpacking objects: 100% (57/57), done.
# /content/consistent_depth
# Submodule 'monodepth/mannequin_challenge' (https://github.com/roxanneluo/mannequinchallenge.git) registered for path 'monodepth/mannequin_challenge'
# Submodule 'monodepth/midas_v2' (https://github.com/roxanneluo/MiDaS-1.git) registered for path 'monodepth/midas_v2'
# Submodule 'monodepth/monodepth2' (https://github.com/roxanneluo/monodepth2.git) registered for path 'monodepth/monodepth2'
# Submodule 'third_party/OpticalFlowToolkit' (https://github.com/roxanneluo/OpticalFlowToolkit.git) registered for path 'third_party/OpticalFlowToolkit'
# Submodule 'third_party/colmap' (https://github.com/colmap/colmap.git) registered for path 'third_party/colmap'
# Submodule 'flownet2' (https://github.com/roxanneluo/flownet2-pytorch.git) registered for path 'third_party/flownet2'
# Cloning into '/content/consistent_depth/monodepth/mannequin_challenge'...
# Cloning into '/content/consistent_depth/monodepth/midas_v2'...
# Cloning into '/content/consistent_depth/monodepth/monodepth2'...
# Cloning into '/content/consistent_depth/third_party/OpticalFlowToolkit'...
# Cloning into '/content/consistent_depth/third_party/colmap'...
# Cloning into '/content/consistent_depth/third_party/flownet2'...
# Submodule path 'monodepth/mannequin_challenge': checked out '826c33d4a9f50eb9bfd4b0eba731d893ccbbfa31'
# Submodule path 'monodepth/midas_v2': checked out '6cae4a6d3198efae398f07220aae4804c2f517ed'
# Submodule path 'monodepth/monodepth2': checked out '22d073ab881c1e3a8cfcdd147467d80b1d103327'
# Submodule path 'third_party/OpticalFlowToolkit': checked out '21e7eccd4f979f56ed4dc6e3ba03a5d90edb9bd7'
# Submodule path 'third_party/colmap': checked out '64d625a996a052cdf4f3f9151e9a5af7b8d6a5e1'
# Submodule 'doc/_build/html' (https://github.com/colmap/colmap.github.io.git) registered for path 'third_party/colmap/doc/_build/html'
# Cloning into '/content/consistent_depth/third_party/colmap/doc/_build/html'...
# Submodule path 'third_party/colmap/doc/_build/html': checked out '751fd602f81d3bb52b45bc3f4757113c18f3cd00'
# Submodule path 'third_party/flownet2': checked out 'e99b5cc2b8dde129cb0273ff43501da59fb9731e'

# %% [markdown]
# ## Prepare Environment

# %% [markdown]
# ### Download model files

# %%
# !./scripts/download_model.sh
# Out:
# allexport      	off
# braceexpand    	on
# emacs          	off
# errexit        	on
# errtrace       	off
# functrace      	off
# hashall        	on
# histexpand     	off
# history        	off
# ignoreeof      	off
# interactive-comments	on
# keyword        	off
# monitor        	off
# noclobber      	off
# noexec         	off
# noglob         	off
# nolog          	off
# notify         	off
# nounset        	off
# onecmd         	off
# physical       	off
# pipefail       	off
# posix          	off
# privileged     	off
# verbose        	off
# vi             	off
# xtrace         	on
# ++ mkdir -p checkpoints
# ++ gdown 'https://drive.google.com/uc?id=1hF8vS6YeHkx3j2pfCeQqqZGwA_PJq_Da' -O checkpoints/flownet2.pth
# Downloading...
# From: https://drive.google.com/uc?id=1hF8vS6YeHkx3j2pfCeQqqZGwA_PJq_Da
# To: /content/consistent_depth/checkpoints/flownet2.pth
# 650MB [00:12, 53.9MB/s]

# %% [markdown]
# ### Install Python Dependencies

# %%
# !./scripts/install.sh

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### [Optional] Install COLMAP
#
# > **COLMAP** is not required for running the demo sequence. But if you want to run on your own video and let **COLMAP** to estimate camera pose, please install **COLMAP**. Installation takes a couple minutes.

# %%
# Install packages
# !sudo apt-get install \
    git \
    cmake \
    build-essential \
    libboost-program-options-dev \
    libboost-filesystem-dev \
    libboost-graph-dev \
    libboost-regex-dev \
    libboost-system-dev \
    libboost-test-dev \
    libeigen3-dev \
    libsuitesparse-dev \
    libfreeimage-dev \
    libgoogle-glog-dev \
    libgflags-dev \
    libglew-dev \
    qtbase5-dev \
    libqt5opengl5-dev \
    libcgal-dev \
    libcgal-qt5-dev

# download precompiled colmap packages
# %pushd /content/
# !wget https://www.dropbox.com/s/zvbw6h8nrlm3hc3/colmap-packages.zip?dl=1 -O colmap-packages.zip
# !unzip colmap-packages.zip -d colmap-packages
# ceres-solver make install
# %cd colmap-packages/
# %pushd ceres-solver/build/
# !sudo make install
# %popd
# colmap make install
# %pushd colmap/build
# !sudo make install
# !CC=/usr/bin/gcc-6 CXX=/usr/bin/g++-6 cmake ..
# %popd
# %popd  # pop /content

# test colmap
# !colmap
# !which colmap
# Out:
# Streaming output truncated to the last 5000 lines.
#    creating: colmap-packages/content/colmap-packages/colmap/build/lib/PoissonRecon/CMakeFiles/poisson_recon_autogen.dir/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/lib/PoissonRecon/libpoisson_recon.a
#   inflating: colmap-packages/content/colmap-packages/colmap/build/lib/PoissonRecon/cmake_install.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/lib/cmake_install.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/Makefile
#   inflating: colmap-packages/content/colmap-packages/colmap/build/detect_cuda_compute_capabilities.cpp
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/Makefile2
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/Makefile.cmake
#  extracting: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/progress.marks
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/feature_tests.bin
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/3.12.0/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/3.12.0/CompilerIdCXX/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/3.12.0/CompilerIdCXX/tmp/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/3.12.0/CompilerIdCXX/CMakeCXXCompilerId.cpp
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/3.12.0/CompilerIdCXX/a.out
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/3.12.0/CompilerIdC/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/3.12.0/CompilerIdC/tmp/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/3.12.0/CompilerIdC/CMakeCCompilerId.c
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/3.12.0/CompilerIdC/a.out
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/3.12.0/CMakeCXXCompiler.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/3.12.0/CMakeCCompiler.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/3.12.0/CMakeSystem.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/3.12.0/CMakeDetermineCompilerABI_C.bin
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/3.12.0/CMakeDetermineCompilerABI_CXX.bin
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/TargetDirectories.txt
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/CMakeTmp/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/uninstall.dir/
#  extracting: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/uninstall.dir/progress.make
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/uninstall.dir/build.make
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/uninstall.dir/cmake_clean.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/uninstall.dir/DependInfo.cmake
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/FindOpenMP/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/FindOpenMP/OpenMPTryFlag.c
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/FindOpenMP/ompver_CXX.bin
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/FindOpenMP/OpenMPCheckVersion.c
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/FindOpenMP/ompver_C.bin
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/FindOpenMP/OpenMPCheckVersion.cpp
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/FindOpenMP/OpenMPTryFlag.cpp
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/feature_tests.c
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/CMakeError.log
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/CMakeDirectoryInformation.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/CMakeOutput.log
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/cmake.check_cache
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources_autogen.dir/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/lib/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/lib/VLFeat/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/lib/FLANN/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/lib/LSD/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/lib/SiftGPU/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/lib/SQLite/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/lib/PBA/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/lib/PoissonRecon/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/progress.make
#  extracting: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/cmake_clean_target.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/build.make
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/cmake_clean.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/link.txt
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/depend.make
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/flags.make
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/DependInfo.cmake
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/src/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/src/exe/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/src/tools/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/src/util/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/src/feature/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/src/optim/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/src/ui/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/src/sfm/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/src/base/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/src/estimators/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/src/controllers/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/src/retrieval/
#    creating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/colmap_sources.dir/src/mvs/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/CMakeRuleHashes.txt
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeFiles/feature_tests.cxx
#   inflating: colmap-packages/content/colmap-packages/colmap/build/install_manifest.txt
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeCache.txt
#   inflating: colmap-packages/content/colmap-packages/colmap/build/COLMAPConfigVersion.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/cmake_install.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/CMakeUninstall.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/COLMAPConfig.cmake
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/Makefile
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/
#  extracting: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/progress.marks
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/progress.make
#  extracting: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/cmake_clean_target.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/build.make
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/util/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/util/misc.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/util/camera_specs.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/util/string.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/util/version.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/util/bitmap.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/util/opengl_utils.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/util/math.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/util/threading.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/util/timer.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/util/logging.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/util/ply.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/util/option_manager.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/util/random.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/CXX.includecache
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/feature/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/feature/types.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/feature/sift.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/feature/extraction.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/feature/matching.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/feature/utils.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/cmake_clean.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/link.txt
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/depend.make
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/depend.internal
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/optim/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/optim/support_measurement.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/optim/progressive_sampler.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/optim/sprt.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/optim/least_absolute_deviations.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/optim/random_sampler.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/optim/bundle_adjustment.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/optim/combination_sampler.cc.o
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/feature_extraction_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/options_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/match_matrix_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/main_window.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/reconstruction_manager_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/point_painter.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/line_painter.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/colormaps.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/image_viewer_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/bundle_adjustment_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/point_viewer_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/reconstruction_stats_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/render_options_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/reconstruction_options_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/undistortion_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/automatic_reconstruction_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/feature_matching_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/qt_utils.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/movie_grabber_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/project_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/triangle_painter.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/license_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/thread_control_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/log_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/render_options.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/model_viewer_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/database_management_widget.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/ui/dense_reconstruction_widget.cc.o
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/sfm/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/sfm/incremental_mapper.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/sfm/incremental_triangulator.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/flags.make
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/line.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/projection.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/camera_models.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/gps.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/database_cache.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/triangulation.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/point3d.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/reconstruction_manager.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/similarity_transform.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/essential_matrix.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/database.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/undistortion.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/image_reader.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/camera_rig.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/correspondence_graph.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/graph_cut.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/point2d.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/homography_matrix.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/camera_database.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/visibility_pyramid.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/image.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/pose.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/track.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/reconstruction.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/polynomial.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/camera.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/warp.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/base/scene_clustering.cc.o
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/estimators/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/estimators/two_view_geometry.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/estimators/generalized_relative_pose.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/estimators/affine_transform.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/estimators/generalized_absolute_pose.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/estimators/triangulation.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/estimators/generalized_absolute_pose_coeffs.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/estimators/essential_matrix.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/estimators/fundamental_matrix.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/estimators/homography_matrix.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/estimators/coordinate_frame.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/estimators/absolute_pose.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/estimators/pose.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/estimators/utils.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/DependInfo.cmake
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/controllers/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/controllers/automatic_reconstruction.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/controllers/incremental_mapper.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/controllers/bundle_adjustment.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/controllers/hierarchical_mapper.cc.o
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/colmap_autogen/
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/colmap_autogen/UYX5XTB5RZ/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/colmap_autogen/UYX5XTB5RZ/qrc_resources.cpp.o
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/retrieval/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/retrieval/geometry.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/retrieval/vote_and_verify.cc.o
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/mvs/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/mvs/fusion.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/mvs/consistency_graph.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/mvs/depth_map.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/mvs/model.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/mvs/normal_map.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/mvs/meshing.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/mvs/image.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap.dir/mvs/workspace.cc.o
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda_autogen.dir/
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/progress.make
#  extracting: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/cmake_clean_target.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/build.make
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/util/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/util/cuda.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/util/cudacc.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/CXX.includecache
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/cmake_clean.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/link.txt
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/depend.make
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/depend.internal
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/flags.make
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/DependInfo.cmake
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/mvs/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/mvs/colmap_cuda_generated_gpu_mat_prng.cu.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/mvs/colmap_cuda_generated_gpu_mat_ref_image.cu.o.Release.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/mvs/colmap_cuda_generated_gpu_mat_ref_image.cu.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/mvs/colmap_cuda_generated_patch_match_cuda.cu.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/mvs/colmap_cuda_generated_gpu_mat_prng.cu.o.cmake.pre-gen
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/mvs/colmap_cuda_generated_gpu_mat_prng.cu.o.Release.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/mvs/colmap_cuda_generated_patch_match_cuda.cu.o.cmake.pre-gen
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/mvs/colmap_cuda_generated_patch_match_cuda.cu.o.depend
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/mvs/patch_match.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/mvs/colmap_cuda_generated_gpu_mat_ref_image.cu.o.depend
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/mvs/colmap_cuda_generated_gpu_mat_prng.cu.o.depend
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/mvs/colmap_cuda_generated_patch_match_cuda.cu.o.Release.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_cuda.dir/mvs/colmap_cuda_generated_gpu_mat_ref_image.cu.o.cmake.pre-gen
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_autogen.dir/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_autogen.dir/RCCresourcesSettings.txt
#  extracting: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_autogen.dir/RCCresources.lock
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/colmap_autogen.dir/RCCresourcesInfo.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/CMakeFiles/CMakeDirectoryInformation.cmake
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/exe/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/exe/colmap
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/exe/Makefile
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/exe/CMakeFiles/
#  extracting: colmap-packages/content/colmap-packages/colmap/build/src/exe/CMakeFiles/progress.marks
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/exe/CMakeFiles/colmap_exe_autogen.dir/
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/exe/CMakeFiles/colmap_exe.dir/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/exe/CMakeFiles/colmap_exe.dir/progress.make
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/exe/CMakeFiles/colmap_exe.dir/colmap.cc.o
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/exe/CMakeFiles/colmap_exe.dir/build.make
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/exe/CMakeFiles/colmap_exe.dir/CXX.includecache
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/exe/CMakeFiles/colmap_exe.dir/cmake_clean.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/exe/CMakeFiles/colmap_exe.dir/link.txt
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/exe/CMakeFiles/colmap_exe.dir/depend.make
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/exe/CMakeFiles/colmap_exe.dir/depend.internal
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/exe/CMakeFiles/colmap_exe.dir/flags.make
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/exe/CMakeFiles/colmap_exe.dir/DependInfo.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/exe/CMakeFiles/CMakeDirectoryInformation.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/exe/cmake_install.cmake
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/tools/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/tools/Makefile
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/tools/CMakeFiles/
#  extracting: colmap-packages/content/colmap-packages/colmap/build/src/tools/CMakeFiles/progress.marks
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/tools/CMakeFiles/CMakeDirectoryInformation.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/tools/cmake_install.cmake
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/util/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/util/Makefile
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/util/CMakeFiles/
#  extracting: colmap-packages/content/colmap-packages/colmap/build/src/util/CMakeFiles/progress.marks
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/util/CMakeFiles/CMakeDirectoryInformation.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/util/cmake_install.cmake
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/feature/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/feature/Makefile
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/feature/CMakeFiles/
#  extracting: colmap-packages/content/colmap-packages/colmap/build/src/feature/CMakeFiles/progress.marks
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/feature/CMakeFiles/CMakeDirectoryInformation.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/feature/cmake_install.cmake
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/optim/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/optim/Makefile
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/optim/CMakeFiles/
#  extracting: colmap-packages/content/colmap-packages/colmap/build/src/optim/CMakeFiles/progress.marks
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/optim/CMakeFiles/CMakeDirectoryInformation.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/optim/cmake_install.cmake
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/ui/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/ui/Makefile
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/ui/CMakeFiles/
#  extracting: colmap-packages/content/colmap-packages/colmap/build/src/ui/CMakeFiles/progress.marks
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/ui/CMakeFiles/CMakeDirectoryInformation.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/ui/cmake_install.cmake
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/sfm/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/sfm/Makefile
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/sfm/CMakeFiles/
#  extracting: colmap-packages/content/colmap-packages/colmap/build/src/sfm/CMakeFiles/progress.marks
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/sfm/CMakeFiles/CMakeDirectoryInformation.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/sfm/cmake_install.cmake
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/base/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/base/Makefile
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/base/CMakeFiles/
#  extracting: colmap-packages/content/colmap-packages/colmap/build/src/base/CMakeFiles/progress.marks
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/base/CMakeFiles/CMakeDirectoryInformation.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/base/cmake_install.cmake
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/estimators/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/estimators/Makefile
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/estimators/CMakeFiles/
#  extracting: colmap-packages/content/colmap-packages/colmap/build/src/estimators/CMakeFiles/progress.marks
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/estimators/CMakeFiles/CMakeDirectoryInformation.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/estimators/cmake_install.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/cmake_install.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/libcolmap.a
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/controllers/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/controllers/Makefile
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/controllers/CMakeFiles/
#  extracting: colmap-packages/content/colmap-packages/colmap/build/src/controllers/CMakeFiles/progress.marks
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/controllers/CMakeFiles/CMakeDirectoryInformation.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/controllers/cmake_install.cmake
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/colmap_autogen/
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/colmap_autogen/UYX5XTB5RZ/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/colmap_autogen/UYX5XTB5RZ/qrc_resources.cpp
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/retrieval/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/retrieval/Makefile
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/retrieval/CMakeFiles/
#  extracting: colmap-packages/content/colmap-packages/colmap/build/src/retrieval/CMakeFiles/progress.marks
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/retrieval/CMakeFiles/CMakeDirectoryInformation.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/retrieval/cmake_install.cmake
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/mvs/
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/mvs/Makefile
#    creating: colmap-packages/content/colmap-packages/colmap/build/src/mvs/CMakeFiles/
#  extracting: colmap-packages/content/colmap-packages/colmap/build/src/mvs/CMakeFiles/progress.marks
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/mvs/CMakeFiles/CMakeDirectoryInformation.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/mvs/cmake_install.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/build/src/libcolmap_cuda.a
#    creating: colmap-packages/content/colmap-packages/colmap/cmake/
#   inflating: colmap-packages/content/colmap-packages/colmap/cmake/FindEigen3.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/cmake/CMakeConfig.cmake.in
#   inflating: colmap-packages/content/colmap-packages/colmap/cmake/FindFreeImage.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/cmake/CMakeHelper.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/cmake/GenerateVersionDefinitions.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/cmake/CMakeConfigVersion.cmake.in
#   inflating: colmap-packages/content/colmap-packages/colmap/cmake/CMakeUninstall.cmake.in
#   inflating: colmap-packages/content/colmap-packages/colmap/cmake/FindGlew.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/cmake/SelectCudaComputeArch.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/cmake/FindGlog.cmake
#   inflating: colmap-packages/content/colmap-packages/colmap/.gitmodules
#   inflating: colmap-packages/content/colmap-packages/colmap/.travis.yml
#    creating: colmap-packages/content/colmap-packages/colmap/doc/
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/Makefile
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/conf.py
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/colmap.1
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/COLMAP.desktop
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/make.bat
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/changelog.rst
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/gui.rst
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/cli.rst
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/faq.rst
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/index.rst
#    creating: colmap-packages/content/colmap-packages/colmap/doc/_build/
#    creating: colmap-packages/content/colmap-packages/colmap/doc/_build/html/
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/license.rst
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/datasets.rst
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/bibliography.rst
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/cameras.rst
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/install.rst
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/contribution.rst
#    creating: colmap-packages/content/colmap-packages/colmap/doc/images/
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/images/incremental-sfm.png
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/images/sparse.png
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/images/dense.png
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/database.rst
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/format.rst
#   inflating: colmap-packages/content/colmap-packages/colmap/doc/tutorial.rst
#   inflating: colmap-packages/content/colmap-packages/colmap/.gitignore
#    creating: colmap-packages/content/colmap-packages/colmap/scripts/
#    creating: colmap-packages/content/colmap-packages/colmap/scripts/python/
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/python/bundler_to_ply.py
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/python/read_write_model.py
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/python/database.py
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/python/flickr_downloader.py
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/python/export_inlier_pairs.py
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/python/read_dense.py
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/python/export_to_visualsfm.py
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/python/export_inlier_matches.py
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/python/clang_format_code.py
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/python/export_to_bundler.py
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/python/nvm_to_ply.py
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/python/merge_ply_files.py
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/python/build.py
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/python/test_read_write_model.py
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/python/crawl_camera_specs.py
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/python/build_windows_app.py
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/python/plyfile.py
#    creating: colmap-packages/content/colmap-packages/colmap/scripts/matlab/
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/matlab/quat2rotmat.m
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/matlab/write_ply.m
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/matlab/read_array.m
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/matlab/read_depth_map.m
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/matlab/write_array.m
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/matlab/read_ply.m
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/matlab/read_model.m
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/matlab/read_normal_map.m
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/matlab/plot_model.m
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/matlab/cmap2rgb.m
#    creating: colmap-packages/content/colmap-packages/colmap/scripts/shell/
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/shell/colmap.bat
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/shell/restore_git_submodules.sh
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/shell/build_mac_app.sh
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/shell/images_to_video.sh
#   inflating: colmap-packages/content/colmap-packages/colmap/scripts/shell/run_tests.bat
#   inflating: colmap-packages/content/colmap-packages/colmap/CMakeLists.txt
#   inflating: colmap-packages/content/colmap-packages/colmap/.appveyor.yml
#   inflating: colmap-packages/content/colmap-packages/colmap/COPYING.txt
#    creating: colmap-packages/content/colmap-packages/colmap/src/
#    creating: colmap-packages/content/colmap-packages/colmap/src/exe/
#   inflating: colmap-packages/content/colmap-packages/colmap/src/exe/colmap.cc
#   inflating: colmap-packages/content/colmap-packages/colmap/src/exe/CMakeLists.txt
#    creating: colmap-packages/content/colmap-packages/colmap/src/tools/
#   inflating: colmap-packages/content/colmap-packages/colmap/src/tools/CMakeLists.txt
#   inflating: colmap-packages/content/colmap-packages/colmap/src/tools/example.cc
#    creating: colmap-packages/content/colmap-packages/colmap/src/util/
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/math.cc
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/bitmap_test.cc
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/camera_specs.cc
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/ply.cc
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/timer.cc
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/matrix.h
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/opengl_utils.h
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/math_test.cc
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/string_test.cc
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/version.h
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/misc.h
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/timer_test.cc
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/string.cc
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/version.h.in
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/cache.h
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/version.cc
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/testing.h
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/random.cc
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/cudacc.cc
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/bitmap.cc
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/endian.h
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/opengl_utils.cc
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/sqlite3_utils.h
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/option_manager.h
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/threading.h
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/camera_specs.h
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/opengl_utils_test.cc
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/cache_test.cc
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/cuda.h
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/threading_test.cc
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/misc_test.cc
#   inflating: colmap-packages/content/colmap-packages/colmap/src/util/random.h
# ...
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/fisher.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/mathop_sse2.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/vlad.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/hikmeans.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/slic.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/shuffle-def.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/mathop.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/qsort-def.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/svmdataset.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/kdtree.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/covdet.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/imopv_sse2.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/float.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/array.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/scalespace.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/mser.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/gmm.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/heap-def.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/homkermap.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/generic.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/mathop_avx.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/hog.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/rodrigues.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/quickshift.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/dsift.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/svm.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/getopt_long.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/lbp.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/random.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/liop.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/stringop.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/host.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/imopv.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/kmeans.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/sift.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/ikmeans.h
# -- Up-to-date: /usr/local/include/colmap/lib/VLFeat/aib.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/CmdLineParser.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/FunctionData.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/MAT.inl
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/MyTime.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/PPolynomial.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/Ply.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/MultiGridOctreeData.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/MultiGridOctreeData.System.inl
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/MemoryUsage.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/SurfaceTrimmer.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/PoissonRecon.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/Octree.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/MAT.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/Allocator.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/PointStream.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/Octree.inl
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/MultiGridOctreeData.inl
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/PointStream.inl
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/Array.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/PPolynomial.inl
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/MultiGridOctreeData.WeightedSamples.inl
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/MarchingCubes.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/Hash.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/Array.inl
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/Geometry.inl
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/BSplineData.inl
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/Factor.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/BinaryNode.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/SparseMatrix.inl
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/Geometry.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/FunctionData.inl
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/MultiGridOctreeData.SortedTreeNodes.inl
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/MultiGridOctreeData.Evaluation.inl
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/CmdLineParser.inl
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/Polynomial.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/SparseMatrix.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/BSplineData.h
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/MultiGridOctreeData.IsoSurface.inl
# -- Up-to-date: /usr/local/include/colmap/lib/PoissonRecon/Polynomial.inl
# -- Up-to-date: /usr/local/include/colmap/lib/Graclus
# -- Up-to-date: /usr/local/include/colmap/lib/Graclus/metisLib
# -- Up-to-date: /usr/local/include/colmap/lib/Graclus/metisLib/metis.h
# -- Up-to-date: /usr/local/include/colmap/lib/Graclus/metisLib/macros.h
# -- Up-to-date: /usr/local/include/colmap/lib/Graclus/metisLib/defs.h
# -- Up-to-date: /usr/local/include/colmap/lib/Graclus/metisLib/rename.h
# -- Up-to-date: /usr/local/include/colmap/lib/Graclus/metisLib/proto.h
# -- Up-to-date: /usr/local/include/colmap/lib/Graclus/metisLib/struct.h
# -- Up-to-date: /usr/local/include/colmap/lib/Graclus/multilevelLib
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/ext
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/ext/lz4hc.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/ext/lz4.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/config.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/defines.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/io
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/io/hdf5.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/nn
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/nn/simplex_downhill.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/nn/ground_truth.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/nn/index_testing.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/config.h.in
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/mpi
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/mpi/server.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/mpi/matrix.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/mpi/client.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/mpi/queries.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/mpi/index.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/general.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/flann.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util/logger.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util/cutil_math.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util/lsh_table.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util/timer.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util/result_set.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util/serialization.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util/object_factory.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util/matrix.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util/sampling.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util/params.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util/heap.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util/dynamic_bitset.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util/saving.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util/random.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util/any.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util/cuda
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util/cuda/result_set.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util/cuda/heap.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/util/allocator.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/flann.hpp
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/algorithms
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/algorithms/kdtree_index.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/algorithms/linear_index.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/algorithms/kmeans_index.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/algorithms/kdtree_cuda_3d_index.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/algorithms/hierarchical_clustering_index.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/algorithms/kdtree_cuda_builder.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/algorithms/composite_index.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/algorithms/nn_index.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/algorithms/dist.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/algorithms/autotuned_index.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/algorithms/all_indices.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/algorithms/lsh_index.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/algorithms/center_chooser.h
# -- Up-to-date: /usr/local/include/colmap/lib/FLANN/algorithms/kdtree_single_index.h
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU/ProgramGPU.h
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU/SiftPyramid.h
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU/SiftMatchCU.h
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU/ShaderMan.h
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU/PyramidCL.h
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU/ProgramGLSL.h
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU/ProgramCG.h
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU/SiftGPU.h
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU/SiftMatch.h
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU/CLTexImage.h
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU/CuTexImage.h
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU/ProgramCL.h
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU/GLTexImage.h
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU/LiteWindow.h
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU/PyramidCU.h
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU/ProgramCU.h
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU/FrameBufferObject.h
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU/PyramidGL.h
# -- Up-to-date: /usr/local/include/colmap/lib/SiftGPU/GlobalUtil.h
# -- Up-to-date: /usr/local/share/colmap/COLMAPConfig.cmake
# -- Up-to-date: /usr/local/share/colmap/COLMAPConfigVersion.cmake
# -- Up-to-date: /usr/local/share/colmap/cmake
# -- Up-to-date: /usr/local/share/colmap/cmake/FindFreeImage.cmake
# -- Up-to-date: /usr/local/share/colmap/cmake/FindGlog.cmake
# -- Up-to-date: /usr/local/share/colmap/cmake/FindEigen3.cmake
# -- Up-to-date: /usr/local/share/colmap/cmake/FindGlew.cmake
# -- Up-to-date: /usr/local/share/applications/COLMAP.desktop
# -- Up-to-date: /usr/local/lib/colmap/libflann.a
# -- Up-to-date: /usr/local/lib/colmap/libgraclus.a
# -- Up-to-date: /usr/local/lib/colmap/liblsd.a
# -- Installing: /usr/local/lib/colmap/libpba.a
# -- Up-to-date: /usr/local/lib/colmap/libpoisson_recon.a
# -- Installing: /usr/local/lib/colmap/libsift_gpu.a
# -- Up-to-date: /usr/local/lib/colmap/libsqlite3.a
# -- Up-to-date: /usr/local/lib/colmap/libvlfeat.a
# -- Up-to-date: /usr/local/lib/colmap/libcolmap.a
# -- Installing: /usr/local/lib/colmap/libcolmap_cuda.a
# -- Installing: /usr/local/bin/colmap
# -- Found required Ceres dependency: Eigen version 3.3.4 in /usr/include/eigen3
# -- Found required Ceres dependency: glog
# -- Found required Ceres dependency: gflags
# -- Found Ceres version: 2.0.0 installed in: /usr/local with components: [EigenSparse, SparseLinearAlgebraLibrary, LAPACK, SuiteSparse, CXSparse, SchurSpecializations, Multithreading]
# -- Boost version: 1.65.1
# -- Found the following Boost libraries:
# --   program_options
# --   filesystem
# --   graph
# --   regex
# --   system
# --   unit_test_framework
# -- Found Eigen
# --   Includes : /usr/include/eigen3
# -- Found FreeImage
# --   Includes : /usr/include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libfreeimage.so
# -- Found Glog
# --   Includes : /usr/include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libglog.so
# CMake Warning (dev) at /usr/local/lib/python2.7/dist-packages/cmake/data/share/cmake-3.12/Modules/FindOpenGL.cmake:270 (message):
#   Policy CMP0072 is not set: FindOpenGL prefers GLVND by default when
#   available.  Run "cmake --help-policy CMP0072" for policy details.  Use the
#   cmake_policy command to set the policy and suppress this warning.
#
#   FindOpenGL found both a legacy GL library:
#
#     OPENGL_gl_LIBRARY: /usr/lib/x86_64-linux-gnu/libGL.so
#
#   and GLVND libraries for OpenGL and GLX:
#
#     OPENGL_opengl_LIBRARY: /usr/lib/x86_64-linux-gnu/libOpenGL.so
#     OPENGL_glx_LIBRARY: /usr/lib/x86_64-linux-gnu/libGLX.so
#
#   OpenGL_GL_PREFERENCE has not been set to "GLVND" or "LEGACY", so for
#   compatibility with CMake 3.10 and below the legacy GL library will be used.
# Call Stack (most recent call first):
#   CMakeLists.txt:103 (find_package)
# This warning is for project developers.  Use -Wno-dev to suppress it.
#
# -- Found Glew
# --   Includes : /usr/include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libGLEW.so
# -- Found Qt
# --   Module : /usr/lib/x86_64-linux-gnu/cmake/Qt5Core
# --   Module : /usr/lib/x86_64-linux-gnu/cmake/Qt5OpenGL
# --   Module : /usr/lib/x86_64-linux-gnu/cmake/Qt5Widgets
# -- Found CGAL
# --   Includes : /usr//include
# --   Libraries : /usr/lib/x86_64-linux-gnu/libCGAL.so.13.0.1
# -- Build type not specified, using Release
# -- Enabling SIMD support
# -- Enabling OpenMP support
# -- Disabling interprocedural optimization
# -- Autodetected CUDA architecture(s):  7.5
# -- Enabling CUDA support (version: 10.1, archs: sm_75)
# -- Enabling OpenGL support
# -- Disabling profiling support
# -- Enabling CGAL support
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /content/colmap-packages/colmap/build
# /content/colmap-packages
# popd -> /content/colmap-packages
# /content/consistent_depth
# popd -> /content/consistent_depth
# COLMAP 3.6 -- Structure-from-Motion and Multi-View Stereo
#               (Commit 0dce1db on 2019-12-09 with CUDA)
#
# Usage:
#   colmap [command] [options]
#
# Documentation:
#   https://colmap.github.io/
#
# Example usage:
#   colmap help [ -h, --help ]
#   colmap gui
#   colmap gui -h [ --help ]
#   colmap automatic_reconstructor -h [ --help ]
#   colmap automatic_reconstructor --image_path IMAGES --workspace_path WORKSPACE
#   colmap feature_extractor --image_path IMAGES --database_path DATABASE
#   colmap exhaustive_matcher --database_path DATABASE
#   colmap mapper --image_path IMAGES --database_path DATABASE --output_path MODEL
#   ...
#
# Available commands:
#   help
#   gui
#   automatic_reconstructor
#   bundle_adjuster
#   color_extractor
#   database_creator
#   database_merger
#   delaunay_mesher
#   exhaustive_matcher
#   feature_extractor
#   feature_importer
#   hierarchical_mapper
#   image_deleter
#   image_filterer
#   image_rectifier
#   image_registrator
#   image_undistorter
#   image_undistorter_standalone
#   mapper
#   matches_importer
#   model_aligner
#   model_analyzer
#   model_converter
#   model_merger
#   model_orientation_aligner
#   patch_match_stereo
#   point_filtering
#   point_triangulator
#   poisson_mesher
#   project_generator
#   rig_bundle_adjuster
#   sequential_matcher
#   spatial_matcher
#   stereo_fusion
#   transitive_matcher
#   vocab_tree_builder
#   vocab_tree_matcher
#   vocab_tree_retriever
#
# /usr/local/bin/colmap

# %% [markdown]
# ## Prepare Input Video
# You can either try out the demo we provied (no need to install COLMAP) or run on your own video sequence (COLMAP required).

# %% [markdown]
# ### Try out Our Demo
# Download the demo video together with its precomputed COLMAP results

# %%
# %%capture
# !./scripts/download_demo.sh results/ayush
path = 'results/ayush'
video_file = 'data/videos/ayush.mp4'
camera_params = "1671.770118, 540, 960" 
camera_model = "SIMPLE_PINHOLE"

# %%
! pip show resample2d_cuda
# Out:
# Name: resample2d-cuda
# Version: 0.0.0
# Summary: UNKNOWN
# Home-page: UNKNOWN
# Author: UNKNOWN
# Author-email: UNKNOWN
# License: UNKNOWN
# Location: /root/.local/lib/python3.6/site-packages/resample2d_cuda-0.0.0-py3.6-linux-x86_64.egg
# Requires:
# Required-by:

# %%
# !cd /root/.local/lib/python3.6/site-packages/

# %%
# Out:
# bash: cannot set terminal process group (56): Inappropriate ioctl for device
# bash: no job control in this shell
# /content/consistent_depth# mark19970912
# bash: mark19970912: command not found
# /content/consistent_depth# admin
# bash: admin: command not found
# /content/consistent_depth#
# /content/consistent_depth#
# /content/consistent_depth#
# Session terminated, terminating shell...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-30fd5ee3e549> in <module>()
# ----> 1 get_ipython().system('su')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     100       kwargs.update({'also_return_output': True})
#     101
# --> 102     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     103
#     104     if pip_warn:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     438   # stack.
#     439   result = _run_command(
# --> 440       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
#     441   shell.user_ns['_exit_code'] = result.returncode
#     442   if -result.returncode in _INTERRUPTED_SIGNALS:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#     193       os.close(child_pty)
#     194
# --> 195       return _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     196   finally:
#     197     epoll.close()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     220   while True:
#     221     try:
# --> 222       result = _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     223       if result is not None:
#     224         return result
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     267   output_available = False
#     268
# --> 269   events = epoll.poll()
#     270   input_events = []
#     271   for _, event in events:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Use Your Own Video
# - [Optional] **Calibrate and set camera parameters** using [`PINHOLE` (fx, fy, cx, cy) or `SIMPLE_PINHOLE` (f, cx, cy) model](https://colmap.github.io/cameras.html).
# Camera intrinsics calibration is optional but suggested for more accurate and faster camera registration. Just leave the fields with default values if you want to skip this step.
# We typically calibrate the camera by capturing a video of a textured plane with really slow camera motion while trying to let target features
# cover the full field of view, selecting non-blurry frames, running **COLMAP** on these images.
# - **Upload your video**. Short video is more desired. As a reference, our system takes about 37min on a 3s video excluding COLMAP reconstruction part when tested with one NVIDIA GeForce RTX 2080 GPU.
# Our system works on videos of static scenes or dynamic scenes containing moderate motion (consistent motion that is not epipolar-aligned or inconsistent motion (e.g., a waving hand)). Consistent motion (e.g., a moving car) can sometimes be aligned with the epipolar geometry and cause our method, like most others, to estimate the wrong depth. As a rule of thumb, large baseline (camera translation) is preferred especially a baseline that is much larger than scene motion. And it is better when the motion is not parallel to the camera motion.

# %%
# Set camera model and parameters.
camera_model = "SIMPLE_PINHOLE" #@param {type:"string"}
camera_params = "" #@param {type:"string"}

# Upload video.
# %mkdir -p data/videos
# %pushd data/videos

from google.colab import files
import os
from os.path import join as pjoin

uploaded = files.upload()
assert len(uploaded) == 1
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

video_file = pjoin('data/videos', list(uploaded.keys())[0])
path = pjoin('results', os.path.splitext(os.path.basename(video_file))[0])
print(f"video file: {video_file}, output path: {path}")
print(f"camera model: {camera_model}, camera parameters: {camera_params}")

# %popd
# Out:
# /content/consistent_depth/data/videos
#      <input type="file" id="files-9d21412f-af68-4936-959f-fd9b10585a5e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d21412f-af68-4936-959f-fd9b10585a5e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving VID_20190919_202641.mp4 to VID_20190919_202641.mp4
# User uploaded file "VID_20190919_202641.mp4" with length 13062940 bytes
# video file: data/videos/VID_20190919_202641.mp4, output path: results/VID_20190919_202641
# camera model: SIMPLE_PINHOLE, camera parameters: 1671.770118, 540, 960
# /content/consistent_depth
# popd -> /content/consistent_depth

# %% [markdown]
# ## Run

# %%
# %%bash -s "$video_file" "$path" "$camera_model" "$camera_params"
# # convert python variables to bash variables
# video_file="$1"
# path="$2"
# camera_model="$3"
# camera_params="$4"

# %%
# !echo "Start!"
# !python main.py --video_file "$video_file" --path "$path" \
  --camera_params "$camera_params" --camera_model "$camera_model" \
  --make_video
# !echo "Done. Your results are saved at $(pwd)/$path."
# !echo "Video results are at $(pwd)/$path/R_hierarchical2_mc/videos/."
# !echo "Disparity maps are at $(pwd)/$path/R_hierarchical2_mc/B0.1_R1.0_PL1-0_LR0.0004_BS4_Oadam/depth"
# Out:
# Start!
# ------------ Parameters -------------
# align: 16
# batch_size: 4
# camera_model: SIMPLE_PINHOLE
# camera_params: 1671.770118, 540, 960
# colmap_bin_path: colmap
# configure: default
# dense_frame_ratio: 0.95
# dense_pixel_ratio: 0.3
# display_freq: 100
# ffmpeg: ffmpeg
# flow_checkpoint: FlowNet2
# flow_ops: ['hierarchical2']
# frame_range: ''
# initialize_pose: False
# lambda_parameter: 0
# lambda_reprojection: 1.0
# lambda_view_baseline: 0.1
# learning_rate: 0.0004
# log_dir: None
# make_video: True
# matcher: exhaustive
# model_type: mc
# num_epochs: 20
# op: all
# optimizer: Adam
# overlap_ratio: 0.2
# path: results/ayush
# print_freq: 1
# refine_intrinsics: False
# save_epoch_freq: 1
# size: 384
# sparse: False
# val_epoch_freq: 1
# video_file: data/videos/ayush.mp4
# -------------------------------------
#
# ----------------------------------
# Processing dataset 'results/ayush'
# ----------------------------------
# Output directory: results/ayush/R_hierarchical2_mc
#
# **************************
# ****  Extracting PTS  ****
# **************************
# ffmpeg -i data/videos/ayush.mp4 -vframes 1 /tmp/tmplh20v4c2.png
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'data/videos/ayush.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:03.07, start: 0.000000, bitrate: 137216 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1080x1920 [SAR 1:1 DAR 9:16], 137224 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/tmp/tmplh20v4c2.png':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: png, rgb24, 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 200 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 png
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.03 bitrate=N/A speed=0.066x
# video:3341kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffprobe data/videos/ayush.mp4 -select_streams v:0 -show_frames | grep pkt_pts_time
# ffprobe version 3.4.8-0ubuntu0.2 Copyright (c) 2007-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'data/videos/ayush.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:03.07, start: 0.000000, bitrate: 137216 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1080x1920 [SAR 1:1 DAR 9:16], 137224 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# 92 frames detected.
# 92 frames detected (1080 x 1920).
# frames.txt exists, checked OK.
#
# *****************************
# ****  Extracting frames  ****
# *****************************
# ffmpeg -i data/videos/ayush.mp4 -start_number 0 -vsync 0 results/ayush/color_full/frame_%06d.png
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'data/videos/ayush.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:03.07, start: 0.000000, bitrate: 137216 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1080x1920 [SAR 1:1 DAR 9:16], 137224 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'results/ayush/color_full/frame_%06d.png':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: png, rgb24, 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 200 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 png
# frame=   92 fps=4.6 q=-0.0 Lsize=N/A time=00:00:03.06 bitrate=N/A speed=0.155x
# video:252330kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# Frames found, checked OK.
#
# ************************************
# ****  Downscaling frames (raw)  ****
# ************************************
# Original size: 1080 x 1920
# Rounding width to closest multiple of 16.
# Resized: 224 x 384
# Frames found, checked OK.
#
# ************************************
# ****  Downscaling frames (png)  ****
# ************************************
# Original size: 1080 x 1920
# Rounding width to closest multiple of 16.
# Resized: 224 x 384
# Frames found, checked OK.
#
# *****************************************
# ****  Downscaling frames (for flow)  ****
# *****************************************
# Original size: 1080 x 1920
# Resized: 576 x 1024
# Frames found, checked OK.
#
# *********************************
# ****  Compute initial depth  ****
# *********************************
# Fine-tuning directory: 'results/ayush/R_hierarchical2_mc/B0.1_R1.0_PL1-0_LR0.0004_BS4_Oadam'
# Dowloading https://storage.googleapis.com/mannequinchallenge-data/checkpoints/best_depth_Ours_Bilinear_inc_3_net_G.pth to checkpoints/mc.pth ...
# Using 1 GPUs.
#
# *********************************
# ****  COLMAP reconstruction  ****
# *********************************
# Checked metadata file exists.
#
# *************************************
# ****  Convert COLMAP depth maps  ****
# *************************************
#
# ************************************
# ****  Compute per-frame scales  ****
# ************************************
# Scale[0]: median=12.453055381774902, std=45.326171875
# Scale[1]: median=12.859382629394531, std=21.29724884033203
# Scale[2]: median=12.838876724243164, std=29.892972946166992
# Scale[3]: median=12.916034698486328, std=10.146594047546387
# Scale[4]: median=12.90224838256836, std=42.51295852661133
# Scale[5]: median=12.9509916305542, std=16.24677848815918
# Scale[6]: median=12.896064758300781, std=73.54042053222656
# Scale[7]: median=12.888432502746582, std=146.69923400878906
# Scale[8]: median=12.957381248474121, std=120.09862518310547
# Scale[9]: median=12.74875259399414, std=46.073238372802734
# Scale[10]: median=12.460959434509277, std=56.35038375854492
# Scale[11]: median=12.435117721557617, std=188.91986083984375
# Scale[12]: median=12.438465118408203, std=13.980864524841309
# Scale[13]: median=12.34194278717041, std=634.605712890625
# Scale[14]: median=12.374727249145508, std=13.351225852966309
# Scale[15]: median=12.204095840454102, std=47.679161071777344
# Scale[16]: median=12.274198532104492, std=14.821556091308594
# Scale[17]: median=12.634218215942383, std=15.29113483428955
# Scale[18]: median=12.711782455444336, std=16.45013427734375
# Scale[19]: median=12.945353507995605, std=23.15257453918457
# Scale[20]: median=13.090564727783203, std=27.784936904907227
# Scale[21]: median=13.088920593261719, std=40.12284851074219
# Scale[22]: median=13.073991775512695, std=37.741943359375
# Scale[23]: median=13.020543098449707, std=53.676719665527344
# Scale[24]: median=12.951847076416016, std=44.48417663574219
# Scale[25]: median=12.870000839233398, std=27.1876220703125
# Scale[26]: median=12.697875022888184, std=24.03880500793457
# Scale[27]: median=12.455821990966797, std=20.95491600036621
# Scale[28]: median=12.206226348876953, std=33.4694709777832
# Scale[29]: median=12.13921070098877, std=15.133471488952637
# Scale[30]: median=12.081038475036621, std=144.18836975097656
# Scale[31]: median=12.095357894897461, std=12.338095664978027
# Scale[32]: median=12.155438423156738, std=9.477376937866211
# Scale[33]: median=12.114645004272461, std=9.471354484558105
# Scale[34]: median=12.053823471069336, std=8.847366333007812
# Scale[35]: median=12.1798734664917, std=8.975281715393066
# Scale[36]: median=12.112043380737305, std=8.963024139404297
# Scale[37]: median=12.71980094909668, std=13.277932167053223
# Scale[38]: median=12.691104888916016, std=11.51571273803711
# Scale[39]: median=12.58683967590332, std=117.26689147949219
# Scale[40]: median=12.85874080657959, std=194.71981811523438
# Scale[41]: median=12.66102123260498, std=153.89364624023438
# Scale[42]: median=12.873579978942871, std=73.77884674072266
# Scale[43]: median=12.685312271118164, std=50.63987350463867
# Scale[44]: median=12.769571304321289, std=76.51171875
# Scale[45]: median=12.761445999145508, std=36.003658294677734
# Scale[46]: median=12.459811210632324, std=732.5476684570312
# Scale[47]: median=12.528995513916016, std=2070.440673828125
# Scale[48]: median=12.429779052734375, std=3221.67138671875
# Scale[49]: median=12.479369163513184, std=25.567508697509766
# Scale[50]: median=12.661711692810059, std=19.30580711364746
# Scale[51]: median=12.754840850830078, std=32.61307907104492
# Scale[52]: median=12.598138809204102, std=21.190317153930664
# Scale[53]: median=12.38505744934082, std=53.50914764404297
# Scale[54]: median=12.352827072143555, std=41.60334014892578
# Scale[55]: median=12.584665298461914, std=29.02195930480957
# Scale[56]: median=12.507797241210938, std=25.787832260131836
# Scale[57]: median=12.353419303894043, std=57.5131721496582
# Scale[58]: median=12.294912338256836, std=33.27599334716797
# Scale[59]: median=12.230215072631836, std=379.2787780761719
# Scale[60]: median=12.097954750061035, std=67.95124053955078
# Scale[61]: median=11.989073753356934, std=77.00846862792969
# Scale[62]: median=11.74415397644043, std=88.69906616210938
# Scale[63]: median=11.622535705566406, std=371.6301574707031
# Scale[64]: median=11.553301811218262, std=1317.6131591796875
# Scale[65]: median=11.43386173248291, std=101.41729736328125
# Scale[66]: median=11.471060752868652, std=21.056503295898438
# Scale[67]: median=11.36703109741211, std=13.122998237609863
# Scale[68]: median=11.240640640258789, std=16.230749130249023
# Scale[69]: median=11.390092849731445, std=15.549543380737305
# Scale[70]: median=11.422184944152832, std=16.058626174926758
# Scale[71]: median=11.424482345581055, std=59.493160247802734
# Scale[72]: median=11.398015022277832, std=58.17573547363281
# Scale[73]: median=11.395796775817871, std=17.34917449951172
# Scale[74]: median=11.517244338989258, std=29.187110900878906
# Scale[75]: median=11.283429145812988, std=24.624902725219727
# Scale[76]: median=11.304621696472168, std=16.635202407836914
# Scale[77]: median=11.139352798461914, std=17.6949462890625
# Scale[78]: median=11.234580993652344, std=157.1329345703125
# Scale[79]: median=11.497421264648438, std=17.35778045654297
# Scale[80]: median=11.432733535766602, std=17.08409881591797
# Scale[81]: median=11.414876937866211, std=70.46219635009766
# Scale[82]: median=11.30200481414795, std=18.79020118713379
# Scale[83]: median=11.43126106262207, std=35.23323059082031
# Scale[84]: median=11.66201400756836, std=3734.7060546875
# Scale[85]: median=11.671321868896484, std=233.55734252929688
# Scale[86]: median=11.84011173248291, std=17.862504959106445
# Scale[87]: median=11.845574378967285, std=161.82102966308594
# Scale[88]: median=11.730175018310547, std=19.13605499267578
# Scale[89]: median=11.700275421142578, std=19.146434783935547
# Scale[90]: median=11.711182594299316, std=19.480663299560547
# Scale[91]: median=11.790703773498535, std=19.026203155517578
# [scales] mean=12.216384048047273, std=0.5687598554741573
# Filtered out frames []
#
# ************************
# ****  Compute flow  ****
# ************************
# Sampled 522 frame pairs.
# Resizing flow to (224, 384)
# Loading pretrained model from 'checkpoints/flownet2.pth'.
#
# ******************************
# ****  Compute flow masks  ****
# ******************************
# Bad frame pair(0, 64). Overlap_ratio= [0.19535900297619047, 0.24519856770833334]
# Filtered 520 / 522 good frame pairs
# Frame distance statistics: max = 32, mean = 3, median = 2
#
# **************************
# ****  Visualize flow  ****
# **************************
#
# ***********************
# ****  Fine-tuning  ****
# ***********************
# 2020-11-20 10:30:10.565382: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ( 0,  1): reprojection: 0.222946, disparity: 1.068043
# ( 0,  2): reprojection: 0.346473, disparity: 0.732167
# ( 0,  4): reprojection: 0.473813, disparity: 1.024400
# ( 0,  8): reprojection: 0.751798, disparity: 1.621100
# ( 0, 16): reprojection: 2.482447, disparity: 0.607917
# ( 0, 32): reprojection: 4.895473, disparity: 0.953210
# ( 1,  2): reprojection: 0.194030, disparity: 0.536996
# ( 1,  3): reprojection: 0.272305, disparity: 0.331961
# ( 2,  3): reprojection: 0.132612, disparity: 0.367373
# ( 2,  4): reprojection: 0.240520, disparity: 0.515188
# ( 2,  6): reprojection: 0.521385, disparity: 0.540116
# ( 3,  4): reprojection: 0.123173, disparity: 0.232064
# ( 3,  5): reprojection: 0.270830, disparity: 0.306468
# ( 4,  5): reprojection: 0.185874, disparity: 0.204796
# ( 4,  6): reprojection: 0.314535, disparity: 0.222187
# ( 4,  8): reprojection: 0.488691, disparity: 0.802544
# ( 4, 12): reprojection: 1.110588, disparity: 1.039186
# ( 5,  6): reprojection: 0.144132, disparity: 0.254130
# ( 5,  7): reprojection: 0.222866, disparity: 0.589447
# ( 6,  7): reprojection: 0.109744, disparity: 0.506565
# ( 6,  8): reprojection: 0.237293, disparity: 0.582421
# ( 6, 10): reprojection: 0.720190, disparity: 0.377321
# ( 7,  8): reprojection: 0.131116, disparity: 0.275128
# ( 7,  9): reprojection: 0.380704, disparity: 0.477184
# ( 8,  9): reprojection: 0.250655, disparity: 0.478518
# ( 8, 10): reprojection: 0.560774, disparity: 0.675122
# ( 8, 12): reprojection: 1.088420, disparity: 1.414282
# ( 8, 16): reprojection: 1.746087, disparity: 1.843324
# ( 8, 24): reprojection: 4.059923, disparity: 0.596342
# ( 9, 10): reprojection: 0.330812, disparity: 0.275476
# ( 9, 11): reprojection: 0.554062, disparity: 0.753949
# (10, 11): reprojection: 0.281952, disparity: 0.591022
# (10, 12): reprojection: 0.426658, disparity: 0.900137
# (10, 14): reprojection: 0.829031, disparity: 1.074758
# (11, 12): reprojection: 0.245617, disparity: 0.382215
# (11, 13): reprojection: 0.464446, disparity: 0.609502
# (12, 13): reprojection: 0.247725, disparity: 0.385518
# (12, 14): reprojection: 0.500685, disparity: 0.273546
# (12, 16): reprojection: 1.082387, disparity: 0.533098
# (12, 20): reprojection: 1.902328, disparity: 0.826971
# (13, 14): reprojection: 0.326941, disparity: 0.359628
# (13, 15): reprojection: 0.535124, disparity: 0.465320
# (14, 15): reprojection: 0.307284, disparity: 0.264162
# (14, 16): reprojection: 0.663914, disparity: 0.547527
# (14, 18): reprojection: 0.926017, disparity: 0.340933
# (15, 16): reprojection: 0.373068, disparity: 0.328523
# (15, 17): reprojection: 0.593159, disparity: 0.437459
# (16, 17): reprojection: 0.266087, disparity: 0.484662
# (16, 18): reprojection: 0.625727, disparity: 0.377149
# (16, 20): reprojection: 1.254461, disparity: 1.104916
# (16, 24): reprojection: 2.438409, disparity: 1.983246
# (16, 32): reprojection: 4.414202, disparity: 0.826200
# (16, 48): reprojection: 2.796811, disparity: 0.605237
# (17, 18): reprojection: 0.421825, disparity: 0.243007
# (17, 19): reprojection: 0.784207, disparity: 0.642287
# (18, 19): reprojection: 0.395546, disparity: 0.696978
# (18, 20): reprojection: 0.657411, disparity: 0.826763
# (18, 22): reprojection: 1.224438, disparity: 1.360539
# (19, 20): reprojection: 0.305946, disparity: 0.282374
# (19, 21): reprojection: 0.645603, disparity: 0.565167
# (20, 21): reprojection: 0.321194, disparity: 0.442553
# (20, 22): reprojection: 0.603771, disparity: 0.585067
# (20, 24): reprojection: 1.092995, disparity: 1.091805
# (20, 28): reprojection: 2.578671, disparity: 1.074691
# (21, 22): reprojection: 0.286133, disparity: 0.351744
# (21, 23): reprojection: 0.524391, disparity: 0.396316
# (22, 23): reprojection: 0.334266, disparity: 0.364255
# (22, 24): reprojection: 0.618026, disparity: 0.631928
# (22, 26): reprojection: 1.275139, disparity: 0.451195
# (23, 24): reprojection: 0.340338, disparity: 0.440446
# (23, 25): reprojection: 0.724520, disparity: 0.471615
# (24, 25): reprojection: 0.282751, disparity: 0.340754
# (24, 26): reprojection: 0.582581, disparity: 0.642863
# (24, 28): reprojection: 1.416477, disparity: 1.821385
# (24, 32): reprojection: 2.710510, disparity: 2.378608
# (24, 40): reprojection: 4.450545, disparity: 1.365996
# (25, 26): reprojection: 0.376881, disparity: 0.475457
# (25, 27): reprojection: 0.621978, disparity: 1.124472
# (26, 27): reprojection: 0.318536, disparity: 0.939908
# (26, 28): reprojection: 0.678523, disparity: 1.486739
# (26, 30): reprojection: 1.304033, disparity: 2.014933
# (27, 28): reprojection: 0.296658, disparity: 0.610441
# (27, 29): reprojection: 0.584130, disparity: 0.680566
# (28, 29): reprojection: 0.339709, disparity: 0.322702
# (28, 30): reprojection: 0.608557, disparity: 0.717569
# (28, 32): reprojection: 1.317645, disparity: 0.555303
# (28, 36): reprojection: 2.101925, disparity: 0.933485
# (29, 30): reprojection: 0.300281, disparity: 0.442076
# (29, 31): reprojection: 0.691618, disparity: 0.535754
# (30, 31): reprojection: 0.327750, disparity: 0.167358
# (30, 32): reprojection: 0.675600, disparity: 0.239121
# (30, 34): reprojection: 1.339456, disparity: 0.418495
# (31, 32): reprojection: 0.259486, disparity: 0.204393
# (31, 33): reprojection: 0.666818, disparity: 0.349930
# (32, 33): reprojection: 0.394192, disparity: 0.323006
# (32, 34): reprojection: 0.654932, disparity: 0.290096
# (32, 36): reprojection: 1.092685, disparity: 0.834645
# (32, 40): reprojection: 2.292027, disparity: 1.888042
# (32, 48): reprojection: 4.540511, disparity: 1.215658
# (32, 64): reprojection: 4.988597, disparity: 0.721097
# (33, 34): reprojection: 0.247521, disparity: 0.201138
# (33, 35): reprojection: 0.569291, disparity: 0.707697
# (34, 35): reprojection: 0.320122, disparity: 0.588101
# (34, 36): reprojection: 0.608236, disparity: 0.776063
# (34, 38): reprojection: 1.296263, disparity: 1.665331
# (35, 36): reprojection: 0.358361, disparity: 0.246603
# (35, 37): reprojection: 0.749439, disparity: 1.175388
# (36, 37): reprojection: 0.465706, disparity: 0.993730
# (36, 38): reprojection: 0.840103, disparity: 1.176595
# (36, 40): reprojection: 1.167957, disparity: 1.127995
# (36, 44): reprojection: 2.352667, disparity: 1.341487
# (37, 38): reprojection: 0.372225, disparity: 0.203366
# (37, 39): reprojection: 0.591167, disparity: 0.295995
# (38, 39): reprojection: 0.366757, disparity: 0.366183
# (38, 40): reprojection: 0.669012, disparity: 0.375205
# (38, 42): reprojection: 1.355522, disparity: 0.462897
# (39, 40): reprojection: 0.393775, disparity: 0.219711
# (39, 41): reprojection: 0.782070, disparity: 0.375483
# (40, 41): reprojection: 0.489610, disparity: 0.270522
# (40, 42): reprojection: 0.849465, disparity: 0.453965
# (40, 44): reprojection: 1.382625, disparity: 0.528477
# (40, 48): reprojection: 2.216490, disparity: 1.323941
# (40, 56): reprojection: 3.503636, disparity: 0.731433
# (41, 42): reprojection: 0.370700, disparity: 0.636010
# (41, 43): reprojection: 0.703243, disparity: 0.422480
# (42, 43): reprojection: 0.351554, disparity: 0.390275
# (42, 44): reprojection: 0.658696, disparity: 0.401343
# (42, 46): reprojection: 1.300672, disparity: 1.931626
# (43, 44): reprojection: 0.300252, disparity: 0.190009
# (43, 45): reprojection: 0.634068, disparity: 0.500214
# (44, 45): reprojection: 0.278495, disparity: 0.448865
# (44, 46): reprojection: 0.617622, disparity: 1.553179
# (44, 48): reprojection: 1.226117, disparity: 1.486724
# (44, 52): reprojection: 2.329766, disparity: 1.315291
# (45, 46): reprojection: 0.327112, disparity: 0.890594
# (45, 47): reprojection: 0.641866, disparity: 1.327130
# (46, 47): reprojection: 0.316046, disparity: 0.424349
# (46, 48): reprojection: 0.640882, disparity: 0.556737
# (46, 50): reprojection: 1.173809, disparity: 1.029475
# (47, 48): reprojection: 0.371266, disparity: 0.320862
# (47, 49): reprojection: 0.644596, disparity: 0.555544
# (48, 49): reprojection: 0.299238, disparity: 0.420416
# (48, 50): reprojection: 0.640844, disparity: 0.661743
# (48, 52): reprojection: 1.218777, disparity: 0.576204
# (48, 56): reprojection: 2.288654, disparity: 0.826591
# (48, 64): reprojection: 4.423501, disparity: 1.187231
# (48, 80): reprojection: 5.410691, disparity: 1.148640
# (49, 50): reprojection: 0.351158, disparity: 0.379698
# (49, 51): reprojection: 0.692389, disparity: 0.462679
# (50, 51): reprojection: 0.361389, disparity: 0.353354
# (50, 52): reprojection: 0.699537, disparity: 0.542435
# (50, 54): reprojection: 1.254653, disparity: 0.667497
# (51, 52): reprojection: 0.353170, disparity: 0.441448
# (51, 53): reprojection: 0.692472, disparity: 0.519685
# (52, 53): reprojection: 0.349185, disparity: 0.390837
# (52, 54): reprojection: 0.665949, disparity: 0.387127
# (52, 56): reprojection: 1.421239, disparity: 0.764238
# (52, 60): reprojection: 2.593204, disparity: 1.210733
# (53, 54): reprojection: 0.320611, disparity: 0.443167
# (53, 55): reprojection: 0.782211, disparity: 0.903683
# (54, 55): reprojection: 0.551455, disparity: 0.655247
# (54, 56): reprojection: 0.945843, disparity: 0.477049
# (54, 58): reprojection: 1.371805, disparity: 0.455843
# (55, 56): reprojection: 0.469871, disparity: 0.377341
# (55, 57): reprojection: 0.709193, disparity: 0.571278
# (56, 57): reprojection: 0.491804, disparity: 0.435954
# (56, 58): reprojection: 1.080533, disparity: 0.621451
# (56, 60): reprojection: 1.835521, disparity: 1.573695
# (56, 64): reprojection: 2.944046, disparity: 2.204253
# (56, 72): reprojection: 5.296658, disparity: 2.104758
# (57, 58): reprojection: 0.575315, disparity: 0.407265
# (57, 59): reprojection: 1.040514, disparity: 0.829188
# (58, 59): reprojection: 0.492872, disparity: 0.475059
# (58, 60): reprojection: 0.852529, disparity: 1.093361
# (58, 62): reprojection: 1.679602, disparity: 1.551593
# (59, 60): reprojection: 0.403218, disparity: 0.751756
# (59, 61): reprojection: 0.809596, disparity: 0.941559
# (60, 61): reprojection: 0.437064, disparity: 0.338319
# (60, 62): reprojection: 0.842525, disparity: 0.920270
# (60, 64): reprojection: 1.633556, disparity: 1.009936
# (60, 68): reprojection: 3.139629, disparity: 1.425924
# (61, 62): reprojection: 0.445753, disparity: 0.914207
# (61, 63): reprojection: 0.883603, disparity: 0.765304
# (62, 63): reprojection: 0.440536, disparity: 0.309952
# (62, 64): reprojection: 0.848272, disparity: 0.427860
# (62, 66): reprojection: 1.830548, disparity: 0.979820
# (63, 64): reprojection: 0.455068, disparity: 0.255662
# (63, 65): reprojection: 0.870078, disparity: 0.549693
# (64, 65): reprojection: 0.447199, disparity: 0.633226
# (64, 66): reprojection: 0.957438, disparity: 0.837953
# (64, 68): reprojection: 2.107923, disparity: 0.975656
# (64, 72): reprojection: 3.870984, disparity: 0.826180
# (64, 80): reprojection: 5.312806, disparity: 1.188283
# (65, 66): reprojection: 0.502779, disparity: 0.337745
# (65, 67): reprojection: 0.885564, disparity: 0.423074
# (66, 67): reprojection: 0.443112, disparity: 0.291612
# (66, 68): reprojection: 0.920309, disparity: 1.007606
# (66, 70): reprojection: 1.706583, disparity: 0.684647
# (67, 68): reprojection: 0.567130, disparity: 0.936116
# (67, 69): reprojection: 0.964858, disparity: 0.847737
# (68, 69): reprojection: 0.570857, disparity: 0.361035
# (68, 70): reprojection: 1.128851, disparity: 0.914307
# (68, 72): reprojection: 2.047568, disparity: 0.964046
# (68, 76): reprojection: 3.318844, disparity: 1.000365
# (69, 70): reprojection: 0.566718, disparity: 0.677452
# (69, 71): reprojection: 1.056485, disparity: 0.999740
# (70, 71): reprojection: 0.487554, disparity: 0.396719
# (70, 72): reprojection: 0.932022, disparity: 0.408323
# (70, 74): reprojection: 1.718396, disparity: 0.510268
# (71, 72): reprojection: 0.516412, disparity: 0.376102
# (71, 73): reprojection: 0.932990, disparity: 0.616263
# (72, 73): reprojection: 0.453821, disparity: 0.433213
# (72, 74): reprojection: 0.891434, disparity: 0.384812
# (72, 76): reprojection: 1.521270, disparity: 0.827296
# (72, 80): reprojection: 2.865860, disparity: 0.944523
# (72, 88): reprojection: 4.282346, disparity: 0.938362
# (73, 74): reprojection: 0.512821, disparity: 0.323898
# (73, 75): reprojection: 0.917373, disparity: 0.610132
# (74, 75): reprojection: 0.468429, disparity: 0.575088
# (74, 76): reprojection: 0.781096, disparity: 0.638494
# (74, 78): reprojection: 1.450710, disparity: 0.642190
# (75, 76): reprojection: 0.378521, disparity: 0.352715
# (75, 77): reprojection: 0.747860, disparity: 0.454247
# (76, 77): reprojection: 0.402372, disparity: 0.356947
# (76, 78): reprojection: 0.746953, disparity: 0.622729
# (76, 80): reprojection: 1.466420, disparity: 0.631086
# (76, 84): reprojection: 2.527575, disparity: 1.413150
# (77, 78): reprojection: 0.384105, disparity: 0.427042
# (77, 79): reprojection: 0.748189, disparity: 0.711669
# (78, 79): reprojection: 0.420538, disparity: 0.363339
# (78, 80): reprojection: 0.701606, disparity: 0.558459
# (78, 82): reprojection: 1.318573, disparity: 0.583767
# (79, 80): reprojection: 0.321297, disparity: 0.463483
# (79, 81): reprojection: 0.660609, disparity: 0.503426
# (80, 81): reprojection: 0.354295, disparity: 0.302026
# (80, 82): reprojection: 0.793706, disparity: 0.559568
# (80, 84): reprojection: 1.443859, disparity: 1.085595
# (80, 88): reprojection: 2.244805, disparity: 0.852621
# (81, 82): reprojection: 0.422611, disparity: 0.413128
# (81, 83): reprojection: 0.754035, disparity: 0.832059
# (82, 83): reprojection: 0.337911, disparity: 0.685749
# (82, 84): reprojection: 0.693586, disparity: 0.788196
# (82, 86): reprojection: 1.238434, disparity: 0.509208
# (83, 84): reprojection: 0.339355, disparity: 0.363694
# (83, 85): reprojection: 0.691770, disparity: 0.715779
# (84, 85): reprojection: 0.345717, disparity: 0.583715
# (84, 86): reprojection: 0.585025, disparity: 0.835164
# (84, 88): reprojection: 1.010433, disparity: 0.711427
# (85, 86): reprojection: 0.265692, disparity: 0.407049
# (85, 87): reprojection: 0.519193, disparity: 0.248494
# (86, 87): reprojection: 0.337732, disparity: 0.371692
# (86, 88): reprojection: 0.517707, disparity: 0.723909
# (86, 90): reprojection: 0.887763, disparity: 0.756557
# (87, 88): reprojection: 0.233372, disparity: 0.567946
# (87, 89): reprojection: 0.441948, disparity: 0.611369
# (88, 89): reprojection: 0.219168, disparity: 0.660131
# (88, 90): reprojection: 0.433405, disparity: 0.805564
# (89, 90): reprojection: 0.232136, disparity: 0.279016
# (89, 91): reprojection: 0.491890, disparity: 0.680074
# (90, 91): reprojection: 0.334915, disparity: 0.633319
# Mean:     reprojection: 0.334915, disparity: 0.633319
# Done Validation for epoch 0 (0 iterations)
# Epoch = 0, pairs = [[0, 8], [82, 86], [16, 24], [70, 71]], loss = 2.4774155616760254
# Epoch = 0, pairs = [[2, 3], [28, 30], [40, 48], [44, 52]], loss = 2.096226692199707
# Epoch = 0, pairs = [[15, 16], [33, 34], [28, 32], [12, 14]], loss = 0.7668867707252502
# Epoch = 0, pairs = [[86, 88], [17, 18], [20, 22], [87, 88]], loss = 0.635270893573761
# Epoch = 0, pairs = [[70, 72], [12, 20], [10, 12], [36, 40]], loss = 1.1571681499481201
# Epoch = 0, pairs = [[71, 72], [79, 80], [12, 16], [64, 80]], loss = 1.399733066558838
# Epoch = 0, pairs = [[4, 12], [54, 55], [58, 59], [16, 18]], loss = 0.642153263092041
# Epoch = 0, pairs = [[73, 75], [4, 8], [32, 48], [56, 60]], loss = 1.7747822999954224
# Epoch = 0, pairs = [[63, 65], [56, 72], [64, 68], [25, 27]], loss = 1.6676199436187744
# Epoch = 0, pairs = [[61, 63], [8, 24], [16, 32], [14, 16]], loss = 1.4647774696350098
# Epoch = 0, pairs = [[51, 52], [83, 84], [20, 21], [9, 11]], loss = 0.5183138847351074
# Epoch = 0, pairs = [[0, 32], [50, 54], [50, 51], [78, 82]], loss = 2.6519713401794434
# Epoch = 0, pairs = [[88, 89], [49, 51], [49, 50], [61, 62]], loss = 0.5256267786026001
# Epoch = 0, pairs = [[45, 46], [57, 59], [56, 57], [8, 16]], loss = 0.7805347442626953
# Epoch = 0, pairs = [[58, 60], [45, 47], [2, 6], [48, 50]], loss = 0.5938544273376465
# Epoch = 0, pairs = [[34, 38], [52, 60], [84, 86], [66, 67]], loss = 0.8770236968994141
# Epoch = 0, pairs = [[32, 34], [12, 13], [22, 26], [8, 12]], loss = 0.6279725432395935
# Epoch = 0, pairs = [[42, 46], [14, 18], [40, 44], [82, 83]], loss = 0.8420952558517456
# Epoch = 0, pairs = [[13, 15], [10, 11], [11, 13], [80, 84]], loss = 0.5153712630271912
# Epoch = 0, pairs = [[72, 76], [34, 36], [40, 56], [76, 77]], loss = 1.2758338451385498
# Epoch = 0, pairs = [[8, 10], [33, 35], [4, 6], [36, 37]], loss = 0.41666531562805176
# Epoch = 0, pairs = [[5, 7], [68, 70], [26, 30], [60, 68]], loss = 0.8401825428009033
# Epoch = 0, pairs = [[69, 71], [18, 19], [7, 9], [31, 33]], loss = 0.4919794797897339
# Epoch = 0, pairs = [[67, 69], [85, 86], [76, 84], [86, 87]], loss = 0.7117643356323242
# Epoch = 0, pairs = [[24, 32], [5, 6], [72, 74], [53, 55]], loss = 0.624404788017273
# Epoch = 0, pairs = [[9, 10], [82, 84], [38, 42], [62, 64]], loss = 0.6248956918716431
# Epoch = 0, pairs = [[65, 67], [85, 87], [36, 44], [19, 20]], loss = 0.6713296175003052
# Epoch = 0, pairs = [[73, 74], [78, 80], [23, 25], [14, 15]], loss = 0.37801724672317505
# Epoch = 0, pairs = [[67, 68], [24, 25], [37, 38], [47, 48]], loss = 0.3458614945411682
# Epoch = 0, pairs = [[8, 9], [55, 56], [56, 64], [22, 24]], loss = 0.7353162169456482
# Epoch = 0, pairs = [[71, 73], [59, 60], [0, 2], [24, 26]], loss = 0.4855133891105652
# Epoch = 0, pairs = [[16, 17], [80, 82], [30, 32], [15, 17]], loss = 0.4224787950515747
# Epoch = 0, pairs = [[39, 40], [48, 56], [22, 23], [84, 88]], loss = 0.677960991859436
# Epoch = 0, pairs = [[76, 78], [28, 36], [24, 40], [30, 34]], loss = 1.0868752002716064
# Epoch = 0, pairs = [[10, 14], [64, 65], [72, 73], [21, 23]], loss = 0.40480276942253113
# Epoch = 0, pairs = [[42, 43], [75, 76], [18, 22], [29, 31]], loss = 0.4564145505428314
# Epoch = 0, pairs = [[20, 28], [74, 75], [38, 39], [3, 4]], loss = 0.5402166843414307
# Epoch = 0, pairs = [[54, 58], [68, 72], [75, 77], [31, 32]], loss = 0.7726504802703857
# Epoch = 0, pairs = [[36, 38], [21, 22], [74, 76], [48, 64]], loss = 0.8998382687568665
# Epoch = 0, pairs = [[68, 76], [32, 64], [1, 2], [43, 44]], loss = 1.0970962047576904
# Epoch = 0, pairs = [[32, 36], [78, 79], [70, 74], [48, 80]], loss = 1.0564699172973633
# Epoch = 0, pairs = [[32, 40], [17, 19], [16, 20], [16, 48]], loss = 1.146813154220581
# Epoch = 0, pairs = [[44, 46], [87, 89], [62, 66], [7, 8]], loss = 0.4888799786567688
# Epoch = 0, pairs = [[55, 57], [81, 82], [51, 53], [68, 69]], loss = 0.4499562978744507
# Epoch = 0, pairs = [[84, 85], [41, 42], [0, 16], [25, 26]], loss = 0.5825414061546326
# Epoch = 0, pairs = [[39, 41], [6, 10], [89, 91], [37, 39]], loss = 0.5363735556602478
# Epoch = 0, pairs = [[47, 49], [42, 44], [52, 53], [57, 58]], loss = 0.4279581308364868
# Epoch = 0, pairs = [[66, 70], [19, 21], [26, 27], [62, 63]], loss = 0.5117002725601196
# Epoch = 0, pairs = [[29, 30], [77, 79], [35, 36], [3, 5]], loss = 0.34421610832214355
# Epoch = 0, pairs = [[83, 85], [72, 80], [30, 31], [54, 56]], loss = 0.6776439547538757
# Epoch = 0, pairs = [[24, 28], [20, 24], [4, 5], [38, 40]], loss = 0.44679054617881775
# Epoch = 0, pairs = [[40, 41], [65, 66], [0, 4], [6, 8]], loss = 0.4063970446586609
# Epoch = 0, pairs = [[35, 37], [60, 61], [90, 91], [44, 45]], loss = 0.3874064087867737
# Epoch = 0, pairs = [[27, 28], [52, 56], [18, 20], [53, 54]], loss = 0.43842604756355286
# Epoch = 0, pairs = [[60, 62], [50, 52], [23, 24], [46, 47]], loss = 0.3865976333618164
# Epoch = 0, pairs = [[72, 88], [60, 64], [0, 1], [1, 3]], loss = 0.8439526557922363
# Epoch = 0, pairs = [[34, 35], [11, 12], [88, 90], [89, 90]], loss = 0.3057042956352234
# Epoch = 0, pairs = [[6, 7], [52, 54], [56, 58], [41, 43]], loss = 0.4253048896789551
# Epoch = 0, pairs = [[77, 78], [32, 33], [64, 72], [66, 68]], loss = 0.5818672180175781
# Epoch = 0, pairs = [[48, 52], [13, 14], [79, 81], [59, 61]], loss = 0.41926002502441406
# Epoch = 0, pairs = [[76, 80], [80, 88], [80, 81], [40, 42]], loss = 0.6300854682922363
# Epoch = 0, pairs = [[74, 78], [63, 64], [26, 28], [2, 4]], loss = 0.3954414129257202
# Epoch = 0, pairs = [[58, 62], [27, 29], [86, 90], [46, 50]], loss = 0.5955134034156799
# Epoch = 0, pairs = [[81, 83], [44, 48], [43, 45], [28, 29]], loss = 0.43397462368011475
# Epoch = 0, pairs = [[46, 48], [48, 49], [64, 66], [69, 70]], loss = 0.39140039682388306
# Epoch 0 took 88.90s.
# ( 0,  1): reprojection: 0.235345, disparity: 0.079775
# ( 0,  2): reprojection: 0.349859, disparity: 0.092561
# ( 0,  4): reprojection: 0.392484, disparity: 0.097904
# ( 0,  8): reprojection: 0.469974, disparity: 0.123707
# ( 0, 16): reprojection: 0.899257, disparity: 0.158339
# ( 0, 32): reprojection: 1.520581, disparity: 0.247579
# ( 1,  2): reprojection: 0.194898, disparity: 0.071256
# ( 1,  3): reprojection: 0.243472, disparity: 0.078859
# ( 2,  3): reprojection: 0.108162, disparity: 0.066655
# ( 2,  4): reprojection: 0.171003, disparity: 0.078379
# ( 2,  6): reprojection: 0.345356, disparity: 0.110165
# ( 3,  4): reprojection: 0.109487, disparity: 0.069970
# ( 3,  5): reprojection: 0.194276, disparity: 0.082096
# ( 4,  5): reprojection: 0.152952, disparity: 0.068220
# ( 4,  6): reprojection: 0.214129, disparity: 0.069565
# ( 4,  8): reprojection: 0.286700, disparity: 0.100294
# ( 4, 12): reprojection: 0.428118, disparity: 0.117558
# ( 5,  6): reprojection: 0.118734, disparity: 0.060895
# ( 5,  7): reprojection: 0.156006, disparity: 0.071481
# ( 6,  7): reprojection: 0.095158, disparity: 0.060308
# ( 6,  8): reprojection: 0.153820, disparity: 0.074200
# ( 6, 10): reprojection: 0.394557, disparity: 0.093504
# ( 7,  8): reprojection: 0.084665, disparity: 0.066493
# ( 7,  9): reprojection: 0.186862, disparity: 0.086574
# ( 8,  9): reprojection: 0.161939, disparity: 0.062112
# ( 8, 10): reprojection: 0.363414, disparity: 0.080129
# ( 8, 12): reprojection: 0.516520, disparity: 0.100705
# ( 8, 16): reprojection: 0.736613, disparity: 0.116751
# ( 8, 24): reprojection: 1.040427, disparity: 0.159900
# ( 9, 10): reprojection: 0.250539, disparity: 0.066760
# ( 9, 11): reprojection: 0.378784, disparity: 0.088438
# (10, 11): reprojection: 0.164235, disparity: 0.064529
# (10, 12): reprojection: 0.214317, disparity: 0.070998
# (10, 14): reprojection: 0.385784, disparity: 0.107069
# (11, 12): reprojection: 0.136521, disparity: 0.056566
# (11, 13): reprojection: 0.231231, disparity: 0.084595
# (12, 13): reprojection: 0.146803, disparity: 0.063586
# (12, 14): reprojection: 0.291227, disparity: 0.093906
# (12, 16): reprojection: 0.488432, disparity: 0.110825
# (12, 20): reprojection: 0.815883, disparity: 0.127247
# (13, 14): reprojection: 0.185920, disparity: 0.065460
# (13, 15): reprojection: 0.265682, disparity: 0.077531
# (14, 15): reprojection: 0.194809, disparity: 0.058534
# (14, 16): reprojection: 0.438023, disparity: 0.087451
# (14, 18): reprojection: 0.392787, disparity: 0.100683
# (15, 16): reprojection: 0.299275, disparity: 0.067882
# (15, 17): reprojection: 0.384289, disparity: 0.093137
# (16, 17): reprojection: 0.136131, disparity: 0.063651
# (16, 18): reprojection: 0.332044, disparity: 0.081783
# (16, 20): reprojection: 0.576299, disparity: 0.099260
# (16, 24): reprojection: 0.914110, disparity: 0.143202
# (16, 32): reprojection: 1.465640, disparity: 0.196373
# (16, 48): reprojection: 1.777578, disparity: 0.264747
# (17, 18): reprojection: 0.320656, disparity: 0.072986
# (17, 19): reprojection: 0.494014, disparity: 0.094550
# (18, 19): reprojection: 0.215453, disparity: 0.062956
# (18, 20): reprojection: 0.297521, disparity: 0.074627
# (18, 22): reprojection: 0.544410, disparity: 0.099183
# (19, 20): reprojection: 0.111825, disparity: 0.059266
# (19, 21): reprojection: 0.267896, disparity: 0.079857
# (20, 21): reprojection: 0.200393, disparity: 0.063276
# (20, 22): reprojection: 0.313431, disparity: 0.078096
# (20, 24): reprojection: 0.427630, disparity: 0.104496
# (20, 28): reprojection: 0.769374, disparity: 0.138349
# (21, 22): reprojection: 0.161679, disparity: 0.057969
# (21, 23): reprojection: 0.261470, disparity: 0.075307
# (22, 23): reprojection: 0.125975, disparity: 0.063949
# (22, 24): reprojection: 0.189522, disparity: 0.081364
# (22, 26): reprojection: 0.372970, disparity: 0.107564
# (23, 24): reprojection: 0.109993, disparity: 0.062787
# (23, 25): reprojection: 0.202047, disparity: 0.091370
# (24, 25): reprojection: 0.137372, disparity: 0.072830
# (24, 26): reprojection: 0.193109, disparity: 0.088852
# (24, 28): reprojection: 0.325234, disparity: 0.113580
# (24, 32): reprojection: 0.666297, disparity: 0.177716
# (24, 40): reprojection: 1.152882, disparity: 0.276293
# (25, 26): reprojection: 0.123494, disparity: 0.069626
# (25, 27): reprojection: 0.224799, disparity: 0.089222
# (26, 27): reprojection: 0.138748, disparity: 0.068180
# (26, 28): reprojection: 0.187162, disparity: 0.083018
# (26, 30): reprojection: 0.373431, disparity: 0.126283
# (27, 28): reprojection: 0.145018, disparity: 0.069911
# (27, 29): reprojection: 0.282600, disparity: 0.097535
# (28, 29): reprojection: 0.187764, disparity: 0.078756
# (28, 30): reprojection: 0.270681, disparity: 0.107606
# (28, 32): reprojection: 0.525428, disparity: 0.142637
# (28, 36): reprojection: 0.820634, disparity: 0.202984
# (29, 30): reprojection: 0.138455, disparity: 0.077020
# (29, 31): reprojection: 0.297226, disparity: 0.095111
# (30, 31): reprojection: 0.188940, disparity: 0.067379
# (30, 32): reprojection: 0.298922, disparity: 0.090640
# (30, 34): reprojection: 0.549910, disparity: 0.140767
# (31, 32): reprojection: 0.148809, disparity: 0.071263
# (31, 33): reprojection: 0.331326, disparity: 0.089996
# (32, 33): reprojection: 0.249426, disparity: 0.072574
# (32, 34): reprojection: 0.268134, disparity: 0.090330
# (32, 36): reprojection: 0.403993, disparity: 0.123224
# (32, 40): reprojection: 0.775400, disparity: 0.180930
# (32, 48): reprojection: 1.175061, disparity: 0.325299
# (32, 64): reprojection: 1.556738, disparity: 0.256597
# (33, 34): reprojection: 0.150667, disparity: 0.078902
# (33, 35): reprojection: 0.279864, disparity: 0.095541
# (34, 35): reprojection: 0.196133, disparity: 0.068695
# (34, 36): reprojection: 0.296584, disparity: 0.107896
# (34, 38): reprojection: 0.466905, disparity: 0.141013
# (35, 36): reprojection: 0.223327, disparity: 0.089638
# (35, 37): reprojection: 0.322704, disparity: 0.096893
# (36, 37): reprojection: 0.279349, disparity: 0.076012
# (36, 38): reprojection: 0.383058, disparity: 0.093683
# (36, 40): reprojection: 0.428144, disparity: 0.126118
# (36, 44): reprojection: 0.801691, disparity: 0.218539
# (37, 38): reprojection: 0.233296, disparity: 0.067918
# (37, 39): reprojection: 0.278227, disparity: 0.091285
# (38, 39): reprojection: 0.197253, disparity: 0.069458
# (38, 40): reprojection: 0.364487, disparity: 0.098472
# (38, 42): reprojection: 0.659278, disparity: 0.142358
# (39, 40): reprojection: 0.278067, disparity: 0.075209
# (39, 41): reprojection: 0.488055, disparity: 0.102357
# (40, 41): reprojection: 0.285420, disparity: 0.081977
# (40, 42): reprojection: 0.406148, disparity: 0.105881
# (40, 44): reprojection: 0.543097, disparity: 0.165356
# (40, 48): reprojection: 0.809272, disparity: 0.250874
# (40, 56): reprojection: 0.957942, disparity: 0.295676
# (41, 42): reprojection: 0.188898, disparity: 0.076582
# (41, 43): reprojection: 0.295177, disparity: 0.109931
# (42, 43): reprojection: 0.170901, disparity: 0.089407
# (42, 44): reprojection: 0.322022, disparity: 0.123671
# (42, 46): reprojection: 0.544048, disparity: 0.170777
# (43, 44): reprojection: 0.203572, disparity: 0.081805
# (43, 45): reprojection: 0.309566, disparity: 0.111313
# (44, 45): reprojection: 0.161091, disparity: 0.078595
# (44, 46): reprojection: 0.293684, disparity: 0.114070
# (44, 48): reprojection: 0.425186, disparity: 0.163810
# (44, 52): reprojection: 0.656517, disparity: 0.190962
# (45, 46): reprojection: 0.205224, disparity: 0.098329
# (45, 47): reprojection: 0.328490, disparity: 0.125383
# (46, 47): reprojection: 0.186809, disparity: 0.081969
# (46, 48): reprojection: 0.292296, disparity: 0.117721
# (46, 50): reprojection: 0.422643, disparity: 0.132205
# (47, 48): reprojection: 0.209293, disparity: 0.082862
# (47, 49): reprojection: 0.283458, disparity: 0.120715
# (48, 49): reprojection: 0.168774, disparity: 0.089113
# (48, 50): reprojection: 0.268894, disparity: 0.093869
# (48, 52): reprojection: 0.391971, disparity: 0.109530
# (48, 56): reprojection: 0.812853, disparity: 0.132656
# (48, 64): reprojection: 1.221251, disparity: 0.199436
# (48, 80): reprojection: 1.713684, disparity: 0.204618
# (49, 50): reprojection: 0.159078, disparity: 0.085859
# (49, 51): reprojection: 0.269881, disparity: 0.092117
# (50, 51): reprojection: 0.157941, disparity: 0.092289
# (50, 52): reprojection: 0.279426, disparity: 0.100785
# (50, 54): reprojection: 0.438020, disparity: 0.143303
# (51, 52): reprojection: 0.168390, disparity: 0.083087
# (51, 53): reprojection: 0.311187, disparity: 0.097559
# (52, 53): reprojection: 0.177368, disparity: 0.085003
# (52, 54): reprojection: 0.272508, disparity: 0.107467
# (52, 56): reprojection: 0.592160, disparity: 0.108290
# (52, 60): reprojection: 0.771969, disparity: 0.172518
# (53, 54): reprojection: 0.131187, disparity: 0.085999
# (53, 55): reprojection: 0.339494, disparity: 0.094341
# (54, 55): reprojection: 0.306980, disparity: 0.075872
# (54, 56): reprojection: 0.584336, disparity: 0.110113
# (54, 58): reprojection: 0.449823, disparity: 0.113534
# (55, 56): reprojection: 0.354076, disparity: 0.091329
# (55, 57): reprojection: 0.430140, disparity: 0.097016
# (56, 57): reprojection: 0.298329, disparity: 0.088817
# (56, 58): reprojection: 0.542629, disparity: 0.114234
# (56, 60): reprojection: 0.731981, disparity: 0.169541
# (56, 64): reprojection: 1.006850, disparity: 0.171605
# (56, 72): reprojection: 1.249141, disparity: 0.193464
# (57, 58): reprojection: 0.336444, disparity: 0.092189
# (57, 59): reprojection: 0.472552, disparity: 0.121952
# (58, 59): reprojection: 0.252555, disparity: 0.097431
# (58, 60): reprojection: 0.393911, disparity: 0.139348
# (58, 62): reprojection: 0.533490, disparity: 0.155823
# (59, 60): reprojection: 0.199899, disparity: 0.131043
# (59, 61): reprojection: 0.335503, disparity: 0.117511
# (60, 61): reprojection: 0.227621, disparity: 0.135779
# (60, 62): reprojection: 0.317398, disparity: 0.136479
# (60, 64): reprojection: 0.533535, disparity: 0.127587
# (60, 68): reprojection: 0.842166, disparity: 0.177330
# (61, 62): reprojection: 0.200776, disparity: 0.096811
# (61, 63): reprojection: 0.289218, disparity: 0.103884
# (62, 63): reprojection: 0.222218, disparity: 0.082840
# (62, 64): reprojection: 0.380151, disparity: 0.114045
# (62, 66): reprojection: 0.594067, disparity: 0.132921
# (63, 64): reprojection: 0.216791, disparity: 0.097204
# (63, 65): reprojection: 0.363031, disparity: 0.109325
# (64, 65): reprojection: 0.211183, disparity: 0.098202
# (64, 66): reprojection: 0.370162, disparity: 0.119040
# (64, 68): reprojection: 0.533179, disparity: 0.133849
# (64, 72): reprojection: 0.940502, disparity: 0.163856
# (64, 80): reprojection: 1.348320, disparity: 0.192174
# (65, 66): reprojection: 0.275606, disparity: 0.095204
# (65, 67): reprojection: 0.446840, disparity: 0.110724
# (66, 67): reprojection: 0.269696, disparity: 0.087920
# (66, 68): reprojection: 0.398097, disparity: 0.102668
# (66, 70): reprojection: 0.558170, disparity: 0.128641
# (67, 68): reprojection: 0.336672, disparity: 0.096121
# (67, 69): reprojection: 0.360290, disparity: 0.099885
# (68, 69): reprojection: 0.217728, disparity: 0.083022
# (68, 70): reprojection: 0.464699, disparity: 0.104050
# (68, 72): reprojection: 0.620906, disparity: 0.129881
# (68, 76): reprojection: 0.894054, disparity: 0.146329
# (69, 70): reprojection: 0.302161, disparity: 0.087940
# (69, 71): reprojection: 0.449724, disparity: 0.097200
# (70, 71): reprojection: 0.217403, disparity: 0.084181
# (70, 72): reprojection: 0.321908, disparity: 0.112072
# (70, 74): reprojection: 0.559244, disparity: 0.124185
# (71, 72): reprojection: 0.244941, disparity: 0.093306
# (71, 73): reprojection: 0.378700, disparity: 0.102696
# (72, 73): reprojection: 0.232297, disparity: 0.090463
# ...
# (10, 14): reprojection: 0.389676, disparity: 0.063760
# (11, 12): reprojection: 0.143002, disparity: 0.043788
# (11, 13): reprojection: 0.232698, disparity: 0.056306
# (12, 13): reprojection: 0.136464, disparity: 0.044876
# (12, 14): reprojection: 0.276505, disparity: 0.051835
# (12, 16): reprojection: 0.495630, disparity: 0.072976
# (12, 20): reprojection: 0.865366, disparity: 0.100589
# (13, 14): reprojection: 0.186902, disparity: 0.045056
# (13, 15): reprojection: 0.276594, disparity: 0.054074
# (14, 15): reprojection: 0.196945, disparity: 0.045807
# (14, 16): reprojection: 0.437269, disparity: 0.059030
# (14, 18): reprojection: 0.436350, disparity: 0.067362
# (15, 16): reprojection: 0.300973, disparity: 0.048487
# (15, 17): reprojection: 0.399761, disparity: 0.059097
# (16, 17): reprojection: 0.150819, disparity: 0.049518
# (16, 18): reprojection: 0.345653, disparity: 0.068274
# (16, 20): reprojection: 0.653715, disparity: 0.090952
# (16, 24): reprojection: 0.992227, disparity: 0.143081
# (16, 32): reprojection: 1.793419, disparity: 0.230457
# (16, 48): reprojection: 2.747186, disparity: 0.471543
# (17, 18): reprojection: 0.306634, disparity: 0.053005
# (17, 19): reprojection: 0.505822, disparity: 0.073303
# (18, 19): reprojection: 0.228536, disparity: 0.052143
# (18, 20): reprojection: 0.336202, disparity: 0.065810
# (18, 22): reprojection: 0.581731, disparity: 0.091942
# (19, 20): reprojection: 0.136434, disparity: 0.048427
# (19, 21): reprojection: 0.287077, disparity: 0.063349
# (20, 21): reprojection: 0.194033, disparity: 0.050831
# (20, 22): reprojection: 0.302445, disparity: 0.067045
# (20, 24): reprojection: 0.463938, disparity: 0.087878
# (20, 28): reprojection: 0.937354, disparity: 0.139308
# (21, 22): reprojection: 0.162759, disparity: 0.051469
# (21, 23): reprojection: 0.286807, disparity: 0.065976
# (22, 23): reprojection: 0.140437, disparity: 0.051644
# (22, 24): reprojection: 0.232514, disparity: 0.065128
# (22, 26): reprojection: 0.443402, disparity: 0.086751
# (23, 24): reprojection: 0.125655, disparity: 0.052584
# (23, 25): reprojection: 0.211118, disparity: 0.064888
# (24, 25): reprojection: 0.139449, disparity: 0.053067
# (24, 26): reprojection: 0.222193, disparity: 0.066666
# (24, 28): reprojection: 0.412180, disparity: 0.087463
# (24, 32): reprojection: 0.811656, disparity: 0.122825
# (24, 40): reprojection: 1.266836, disparity: 0.210789
# (25, 26): reprojection: 0.151807, disparity: 0.056879
# (25, 27): reprojection: 0.281985, disparity: 0.069596
# (26, 27): reprojection: 0.158958, disparity: 0.055224
# (26, 28): reprojection: 0.220943, disparity: 0.067624
# (26, 30): reprojection: 0.397216, disparity: 0.092172
# (27, 28): reprojection: 0.139558, disparity: 0.057566
# (27, 29): reprojection: 0.269643, disparity: 0.070438
# (28, 29): reprojection: 0.173285, disparity: 0.056906
# (28, 30): reprojection: 0.260468, disparity: 0.073459
# (28, 32): reprojection: 0.514280, disparity: 0.090167
# (28, 36): reprojection: 0.846990, disparity: 0.151109
# (29, 30): reprojection: 0.136142, disparity: 0.055981
# (29, 31): reprojection: 0.312412, disparity: 0.067498
# (30, 31): reprojection: 0.192338, disparity: 0.054898
# (30, 32): reprojection: 0.294205, disparity: 0.063987
# (30, 34): reprojection: 0.565715, disparity: 0.088600
# (31, 32): reprojection: 0.132972, disparity: 0.053187
# (31, 33): reprojection: 0.331783, disparity: 0.066831
# (32, 33): reprojection: 0.248147, disparity: 0.055618
# (32, 34): reprojection: 0.280627, disparity: 0.067728
# (32, 36): reprojection: 0.426656, disparity: 0.099202
# (32, 40): reprojection: 0.621517, disparity: 0.133747
# (32, 48): reprojection: 1.256038, disparity: 0.143886
# (32, 64): reprojection: 2.237533, disparity: 0.191580
# (33, 34): reprojection: 0.145622, disparity: 0.053584
# (33, 35): reprojection: 0.289137, disparity: 0.062142
# (34, 35): reprojection: 0.188914, disparity: 0.053567
# (34, 36): reprojection: 0.288771, disparity: 0.077472
# (34, 38): reprojection: 0.472540, disparity: 0.093117
# (35, 36): reprojection: 0.219636, disparity: 0.066247
# (35, 37): reprojection: 0.284538, disparity: 0.088193
# (36, 37): reprojection: 0.276709, disparity: 0.061739
# (36, 38): reprojection: 0.402729, disparity: 0.070892
# (36, 40): reprojection: 0.369833, disparity: 0.082642
# (36, 44): reprojection: 0.776612, disparity: 0.102542
# (37, 38): reprojection: 0.232641, disparity: 0.054978
# (37, 39): reprojection: 0.271284, disparity: 0.067894
# (38, 39): reprojection: 0.184341, disparity: 0.059150
# (38, 40): reprojection: 0.345939, disparity: 0.072035
# (38, 42): reprojection: 0.627422, disparity: 0.089466
# (39, 40): reprojection: 0.267171, disparity: 0.059080
# (39, 41): reprojection: 0.471250, disparity: 0.071561
# (40, 41): reprojection: 0.279196, disparity: 0.060637
# (40, 42): reprojection: 0.397176, disparity: 0.070707
# (40, 44): reprojection: 0.550682, disparity: 0.084809
# (40, 48): reprojection: 0.874258, disparity: 0.096066
# (40, 56): reprojection: 1.071690, disparity: 0.188366
# (41, 42): reprojection: 0.184415, disparity: 0.060960
# (41, 43): reprojection: 0.308298, disparity: 0.068102
# (42, 43): reprojection: 0.177088, disparity: 0.060910
# (42, 44): reprojection: 0.334042, disparity: 0.073168
# (42, 46): reprojection: 0.574173, disparity: 0.081643
# (43, 44): reprojection: 0.205541, disparity: 0.060029
# (43, 45): reprojection: 0.313769, disparity: 0.075086
# (44, 45): reprojection: 0.149955, disparity: 0.062033
# (44, 46): reprojection: 0.299090, disparity: 0.074716
# (44, 48): reprojection: 0.470371, disparity: 0.087526
# (44, 52): reprojection: 0.731604, disparity: 0.102500
# (45, 46): reprojection: 0.209310, disparity: 0.063756
# (45, 47): reprojection: 0.337941, disparity: 0.078712
# (46, 47): reprojection: 0.192492, disparity: 0.064573
# (46, 48): reprojection: 0.316454, disparity: 0.083212
# (46, 50): reprojection: 0.446715, disparity: 0.106712
# (47, 48): reprojection: 0.214474, disparity: 0.061803
# (47, 49): reprojection: 0.284673, disparity: 0.074957
# (48, 49): reprojection: 0.164867, disparity: 0.072557
# (48, 50): reprojection: 0.261405, disparity: 0.089998
# (48, 52): reprojection: 0.411020, disparity: 0.104105
# (48, 56): reprojection: 0.786889, disparity: 0.115777
# (48, 64): reprojection: 1.416911, disparity: 0.252956
# (48, 80): reprojection: 2.385014, disparity: 0.216889
# (49, 50): reprojection: 0.155713, disparity: 0.069514
# (49, 51): reprojection: 0.276823, disparity: 0.078565
# (50, 51): reprojection: 0.163340, disparity: 0.063241
# (50, 52): reprojection: 0.291313, disparity: 0.079909
# (50, 54): reprojection: 0.447346, disparity: 0.091535
# (51, 52): reprojection: 0.171957, disparity: 0.069599
# (51, 53): reprojection: 0.331253, disparity: 0.074367
# (52, 53): reprojection: 0.180437, disparity: 0.064267
# (52, 54): reprojection: 0.277563, disparity: 0.076716
# (52, 56): reprojection: 0.564297, disparity: 0.077258
# (52, 60): reprojection: 0.805029, disparity: 0.127640
# (53, 54): reprojection: 0.127531, disparity: 0.063757
# (53, 55): reprojection: 0.335592, disparity: 0.075186
# (54, 55): reprojection: 0.307450, disparity: 0.065930
# (54, 56): reprojection: 0.563780, disparity: 0.065935
# (54, 58): reprojection: 0.436593, disparity: 0.100322
# (55, 56): reprojection: 0.348089, disparity: 0.064496
# (55, 57): reprojection: 0.416786, disparity: 0.084082
# (56, 57): reprojection: 0.300000, disparity: 0.074648
# (56, 58): reprojection: 0.562572, disparity: 0.098133
# (56, 60): reprojection: 0.741086, disparity: 0.134335
# (56, 64): reprojection: 1.131735, disparity: 0.159009
# (56, 72): reprojection: 1.636977, disparity: 0.235350
# (57, 58): reprojection: 0.356001, disparity: 0.074075
# (57, 59): reprojection: 0.488216, disparity: 0.086219
# (58, 59): reprojection: 0.254468, disparity: 0.072338
# (58, 60): reprojection: 0.401797, disparity: 0.077526
# (58, 62): reprojection: 0.579938, disparity: 0.116900
# (59, 60): reprojection: 0.207521, disparity: 0.073295
# (59, 61): reprojection: 0.351062, disparity: 0.084696
# (60, 61): reprojection: 0.231593, disparity: 0.079706
# (60, 62): reprojection: 0.357373, disparity: 0.094827
# (60, 64): reprojection: 0.573270, disparity: 0.100735
# (60, 68): reprojection: 0.843768, disparity: 0.151580
# (61, 62): reprojection: 0.227168, disparity: 0.075254
# (61, 63): reprojection: 0.320088, disparity: 0.083617
# (62, 63): reprojection: 0.223904, disparity: 0.069917
# (62, 64): reprojection: 0.348706, disparity: 0.075087
# (62, 66): reprojection: 0.563503, disparity: 0.098112
# (63, 64): reprojection: 0.218733, disparity: 0.069687
# (63, 65): reprojection: 0.348500, disparity: 0.076818
# (64, 65): reprojection: 0.217198, disparity: 0.073709
# (64, 66): reprojection: 0.377613, disparity: 0.073609
# (64, 68): reprojection: 0.529118, disparity: 0.094642
# (64, 72): reprojection: 1.014329, disparity: 0.133406
# (64, 80): reprojection: 1.709911, disparity: 0.124932
# (65, 66): reprojection: 0.281848, disparity: 0.064741
# (65, 67): reprojection: 0.428637, disparity: 0.071302
# (66, 67): reprojection: 0.258861, disparity: 0.069412
# (66, 68): reprojection: 0.392299, disparity: 0.076829
# (66, 70): reprojection: 0.596726, disparity: 0.092345
# (67, 68): reprojection: 0.342373, disparity: 0.067353
# (67, 69): reprojection: 0.364603, disparity: 0.077311
# (68, 69): reprojection: 0.226151, disparity: 0.065367
# (68, 70): reprojection: 0.482192, disparity: 0.074611
# (68, 72): reprojection: 0.677392, disparity: 0.101252
# (68, 76): reprojection: 1.001423, disparity: 0.096924
# (69, 70): reprojection: 0.298397, disparity: 0.064979
# (69, 71): reprojection: 0.455146, disparity: 0.071824
# (70, 71): reprojection: 0.207989, disparity: 0.068364
# (70, 72): reprojection: 0.334993, disparity: 0.086014
# (70, 74): reprojection: 0.600979, disparity: 0.085811
# (71, 72): reprojection: 0.236423, disparity: 0.073139
# (71, 73): reprojection: 0.385526, disparity: 0.075868
# (72, 73): reprojection: 0.241888, disparity: 0.066422
# (72, 74): reprojection: 0.360855, disparity: 0.073415
# (72, 76): reprojection: 0.501956, disparity: 0.082090
# (72, 80): reprojection: 0.982521, disparity: 0.101885
# (72, 88): reprojection: 1.258566, disparity: 0.112168
# (73, 74): reprojection: 0.327973, disparity: 0.066239
# (73, 75): reprojection: 0.467899, disparity: 0.072545
# (74, 75): reprojection: 0.246246, disparity: 0.064426
# (74, 76): reprojection: 0.303050, disparity: 0.067798
# (74, 78): reprojection: 0.444320, disparity: 0.077003
# (75, 76): reprojection: 0.219105, disparity: 0.062860
# (75, 77): reprojection: 0.348522, disparity: 0.071143
# (76, 77): reprojection: 0.230115, disparity: 0.063062
# (76, 78): reprojection: 0.353099, disparity: 0.066779
# (76, 80): reprojection: 0.510258, disparity: 0.085348
# (76, 84): reprojection: 0.839465, disparity: 0.096931
# (77, 78): reprojection: 0.226796, disparity: 0.062286
# (77, 79): reprojection: 0.276362, disparity: 0.072351
# (78, 79): reprojection: 0.210750, disparity: 0.066059
# (78, 80): reprojection: 0.292865, disparity: 0.076919
# (78, 82): reprojection: 0.486739, disparity: 0.084298
# (79, 80): reprojection: 0.156262, disparity: 0.064445
# (79, 81): reprojection: 0.279729, disparity: 0.067680
# (80, 81): reprojection: 0.160629, disparity: 0.060255
# (80, 82): reprojection: 0.311304, disparity: 0.068059
# (80, 84): reprojection: 0.541190, disparity: 0.072848
# (80, 88): reprojection: 0.911488, disparity: 0.089203
# (81, 82): reprojection: 0.207776, disparity: 0.060131
# (81, 83): reprojection: 0.318258, disparity: 0.067337
# (82, 83): reprojection: 0.156059, disparity: 0.062101
# (82, 84): reprojection: 0.299367, disparity: 0.065442
# (82, 86): reprojection: 0.499641, disparity: 0.079857
# (83, 84): reprojection: 0.155775, disparity: 0.057942
# (83, 85): reprojection: 0.325849, disparity: 0.069630
# (84, 85): reprojection: 0.187549, disparity: 0.057314
# (84, 86): reprojection: 0.284587, disparity: 0.066583
# (84, 88): reprojection: 0.522166, disparity: 0.073178
# (85, 86): reprojection: 0.169680, disparity: 0.056047
# (85, 87): reprojection: 0.303792, disparity: 0.064606
# (86, 87): reprojection: 0.239595, disparity: 0.059192
# (86, 88): reprojection: 0.330923, disparity: 0.067134
# (86, 90): reprojection: 0.508877, disparity: 0.073736
# (87, 88): reprojection: 0.170284, disparity: 0.057721
# (87, 89): reprojection: 0.282783, disparity: 0.066529
# (88, 89): reprojection: 0.145501, disparity: 0.056438
# (88, 90): reprojection: 0.316713, disparity: 0.062847
# (89, 90): reprojection: 0.214972, disparity: 0.057843
# (89, 91): reprojection: 0.415337, disparity: 0.076872
# (90, 91): reprojection: 0.321707, disparity: 0.066016
# Mean:     reprojection: 0.321707, disparity: 0.066016
# Done Validation for epoch 7 (1820 iterations)
# Epoch = 7, pairs = [[78, 80], [74, 75], [83, 85], [32, 64]], loss = 0.8262063264846802
# Epoch = 7, pairs = [[1, 3], [39, 41], [32, 40], [0, 8]], loss = 0.5447720289230347
# Epoch = 7, pairs = [[34, 38], [7, 8], [11, 12], [26, 28]], loss = 0.2643301486968994
# Epoch = 7, pairs = [[23, 25], [9, 10], [28, 30], [69, 71]], loss = 0.3875800371170044
# Epoch = 7, pairs = [[74, 78], [64, 65], [14, 15], [26, 27]], loss = 0.3272359371185303
# Epoch = 7, pairs = [[43, 45], [76, 84], [55, 57], [46, 50]], loss = 0.593726396560669
# Epoch = 7, pairs = [[86, 90], [0, 32], [34, 35], [42, 43]], loss = 0.7574730515480042
# Epoch = 7, pairs = [[72, 73], [18, 19], [53, 55], [48, 80]], loss = 0.8058879971504211
# Epoch = 7, pairs = [[37, 38], [19, 20], [40, 44], [48, 52]], loss = 0.43074268102645874
# Epoch = 7, pairs = [[81, 83], [43, 44], [66, 67], [66, 70]], loss = 0.45650407671928406
# Epoch = 7, pairs = [[67, 69], [32, 33], [18, 20], [78, 79]], loss = 0.42200592160224915
# Epoch = 7, pairs = [[12, 16], [44, 45], [68, 69], [22, 24]], loss = 0.5495337843894958
# Epoch = 7, pairs = [[2, 6], [50, 52], [16, 17], [48, 64]], loss = 1.2041898965835571
# Epoch = 7, pairs = [[77, 78], [56, 58], [16, 24], [55, 56]], loss = 0.8324808478355408
# Epoch = 7, pairs = [[77, 79], [50, 54], [8, 9], [5, 6]], loss = 0.3902433216571808
# Epoch = 7, pairs = [[20, 21], [62, 64], [42, 46], [8, 24]], loss = 0.8545252680778503
# Epoch = 7, pairs = [[17, 19], [24, 26], [24, 32], [72, 80]], loss = 0.6651797890663147
# Epoch = 7, pairs = [[0, 4], [62, 66], [20, 28], [48, 56]], loss = 0.7617220282554626
# Epoch = 7, pairs = [[80, 82], [27, 29], [8, 10], [13, 14]], loss = 0.39695513248443604
# Epoch = 7, pairs = [[86, 87], [13, 15], [35, 37], [52, 54]], loss = 0.4026545584201813
# Epoch = 7, pairs = [[4, 8], [40, 42], [0, 16], [70, 71]], loss = 0.7571382522583008
# Epoch = 7, pairs = [[47, 49], [24, 40], [44, 48], [72, 74]], loss = 0.9597242474555969
# Epoch = 7, pairs = [[10, 14], [88, 90], [9, 11], [84, 85]], loss = 0.45006489753723145
# Epoch = 7, pairs = [[12, 20], [41, 42], [12, 14], [48, 49]], loss = 0.4236610531806946
# Epoch = 7, pairs = [[28, 32], [32, 34], [67, 68], [84, 86]], loss = 0.406594455242157
# Epoch = 7, pairs = [[2, 4], [54, 55], [50, 51], [41, 43]], loss = 0.30929112434387207
# Epoch = 7, pairs = [[73, 75], [8, 16], [29, 31], [6, 7]], loss = 0.5291522145271301
# Epoch = 7, pairs = [[82, 83], [4, 5], [40, 48], [30, 32]], loss = 0.5428658127784729
# Epoch = 7, pairs = [[19, 21], [90, 91], [44, 52], [72, 76]], loss = 0.6976626515388489
# Epoch = 7, pairs = [[65, 67], [57, 58], [46, 47], [20, 24]], loss = 0.530051589012146
# Epoch = 7, pairs = [[40, 56], [56, 60], [44, 46], [82, 86]], loss = 0.9021654725074768
# Epoch = 7, pairs = [[33, 35], [40, 41], [89, 91], [31, 33]], loss = 0.40875083208084106
# Epoch = 7, pairs = [[31, 32], [4, 6], [61, 62], [17, 18]], loss = 0.27609506249427795
# Epoch = 7, pairs = [[75, 77], [42, 44], [79, 81], [87, 88]], loss = 0.3621991276741028
# Epoch = 7, pairs = [[6, 8], [83, 84], [51, 53], [34, 36]], loss = 0.3072696328163147
# Epoch = 7, pairs = [[28, 36], [36, 38], [46, 48], [18, 22]], loss = 0.6037836670875549
# Epoch = 7, pairs = [[21, 23], [80, 81], [79, 80], [63, 65]], loss = 0.3515046536922455
# Epoch = 7, pairs = [[48, 50], [57, 59], [78, 82], [70, 72]], loss = 0.5710833668708801
# Epoch = 7, pairs = [[68, 76], [16, 32], [52, 53], [64, 80]], loss = 1.3953779935836792
# Epoch = 7, pairs = [[23, 24], [76, 77], [82, 84], [10, 12]], loss = 0.2620207667350769
# Epoch = 7, pairs = [[59, 60], [54, 56], [45, 46], [69, 70]], loss = 0.40367409586906433
# Epoch = 7, pairs = [[8, 12], [49, 51], [30, 34], [2, 3]], loss = 0.5256929397583008

# %%
pwd
# Out:
# Package                       Version
# ----------------------------- ---------------
# absl-py                       0.10.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.1.0
# argon2-cffi                   20.1.0
# asgiref                       3.3.0
# astor                         0.8.1
# astropy                       4.1
# astunparse                    1.6.3
# async-generator               1.10
# atari-py                      0.2.6
# atomicwrites                  1.4.0
# attrs                         20.2.0
# audioread                     2.1.9
# autograd                      1.3
# Babel                         2.8.0
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        3.2.1
# blis                          0.4.1
# bokeh                         2.1.1
# Bottleneck                    1.3.2
# branca                        0.4.1
# bs4                           0.0.1
# CacheControl                  0.12.6
# cachetools                    4.1.1
# catalogue                     1.0.0
# certifi                       2020.6.20
# cffi                          1.14.3
# chainer                       7.4.0
# channelnorm-cuda              0.0.0
# chardet                       3.0.4
# click                         7.1.2
# cloudpickle                   1.3.0
# cmake                         3.12.0
# cmdstanpy                     0.9.5
# colorama                      0.4.4
# colorlover                    0.3.0
# community                     1.0.0b1
# contextlib2                   0.5.5
# convertdate                   2.2.2
# correlation-cuda              0.0.0
# coverage                      3.7.1
# coveralls                     0.5
# crcmod                        1.7
# cufflinks                     0.17.3
# cupy-cuda101                  7.4.0
# cvxopt                        1.2.5
# cvxpy                         1.0.31
# cycler                        0.10.0
# cymem                         2.0.4
# Cython                        0.29.21
# daft                          0.0.4
# dask                          2.12.0
# dataclasses                   0.7
# datascience                   0.10.6
# debugpy                       1.0.0
# decorator                     4.4.2
# defusedxml                    0.6.0
# descartes                     1.1.0
# dill                          0.3.3
# distributed                   1.25.3
# Django                        3.1.3
# dlib                          19.18.0
# dm-tree                       0.1.5
# docopt                        0.6.2
# docutils                      0.16
# dopamine-rl                   1.0.5
# earthengine-api               0.1.238
# easydict                      1.9
# ecos                          2.0.7.post1
# editdistance                  0.5.3
# en-core-web-sm                2.2.5
# entrypoints                   0.3
# ephem                         3.7.7.1
# et-xmlfile                    1.0.1
# fa2                           0.3.5
# fancyimpute                   0.4.3
# fastai                        1.0.61
# fastdtw                       0.3.4
# fastprogress                  1.0.0
# fastrlock                     0.5
# fbprophet                     0.7.1
# feather-format                0.4.1
# filelock                      3.0.12
# firebase-admin                4.4.0
# fix-yahoo-finance             0.0.22
# Flask                         1.1.2
# folium                        0.8.3
# future                        0.16.0
# gast                          0.3.3
# GDAL                          2.2.2
# gdown                         3.6.4
# gensim                        3.6.0
# geographiclib                 1.50
# geopy                         1.17.0
# gin-config                    0.3.0
# glob2                         0.7
# google                        2.0.3
# google-api-core               1.16.0
# google-api-python-client      1.7.12
# google-auth                   1.17.2
# google-auth-httplib2          0.0.4
# google-auth-oauthlib          0.4.2
# google-cloud-bigquery         1.21.0
# google-cloud-bigquery-storage 1.1.0
# google-cloud-core             1.0.3
# google-cloud-datastore        1.8.0
# google-cloud-firestore        1.7.0
# google-cloud-language         1.2.0
# google-cloud-storage          1.18.1
# google-cloud-translate        1.5.0
# google-colab                  1.0.0
# google-pasta                  0.2.0
# google-resumable-media        0.4.1
# googleapis-common-protos      1.52.0
# googledrivedownloader         0.4
# graphviz                      0.10.1
# grpcio                        1.33.2
# gspread                       3.0.1
# gspread-dataframe             3.0.8
# gym                           0.17.3
# h5py                          2.10.0
# HeapDict                      1.0.1
# holidays                      0.10.3
# holoviews                     1.13.5
# html5lib                      1.0.1
# httpimport                    0.5.18
# httplib2                      0.17.4
# httplib2shim                  0.0.3
# humanize                      0.5.1
# hyperopt                      0.1.2
# ideep4py                      2.0.0.post3
# idna                          2.10
# image                         1.5.33
# imageio                       2.4.1
# imagesize                     1.2.0
# imbalanced-learn              0.4.3
# imblearn                      0.0
# imgaug                        0.2.9
# importlib-metadata            2.0.0
# importlib-resources           3.3.0
# imutils                       0.5.3
# inflect                       2.1.0
# iniconfig                     1.1.1
# intel-openmp                  2020.0.133
# intervaltree                  2.1.0
# ipykernel                     4.10.1
# ipython                       5.5.0
# ipython-genutils              0.2.0
# ipython-sql                   0.3.9
# ipywidgets                    7.5.1
# itsdangerous                  1.1.0
# jax                           0.2.4
# jaxlib                        0.1.56+cuda101
# jdcal                         1.4.1
# jedi                          0.17.2
# jieba                         0.42.1
# Jinja2                        2.11.2
# joblib                        0.17.0
# jpeg4py                       0.1.4
# jsonschema                    2.6.0
# jupyter                       1.0.0
# jupyter-client                5.3.5
# jupyter-console               5.2.0
# jupyter-core                  4.6.3
# jupyterlab-pygments           0.1.2
# kaggle                        1.5.9
# kapre                         0.1.3.1
# Keras                         2.4.3
# Keras-Preprocessing           1.1.2
# keras-vis                     0.4.1
# kiwisolver                    1.3.1
# knnimpute                     0.1.0
# korean-lunar-calendar         0.2.1
# librosa                       0.6.3
# lightgbm                      2.2.3
# llvmlite                      0.31.0
# lmdb                          0.99
# lucid                         0.3.8
# LunarCalendar                 0.0.9
# lxml                          4.2.6
# Markdown                      3.3.3
# MarkupSafe                    1.1.1
# matplotlib                    3.2.2
# matplotlib-venn               0.11.6
# missingno                     0.4.2
# mistune                       0.8.4
# mizani                        0.6.0
# mkl                           2019.0
# mlxtend                       0.14.0
# more-itertools                8.6.0
# moviepy                       0.2.3.5
# mpmath                        1.1.0
# msgpack                       1.0.0
# multiprocess                  0.70.10
# multitasking                  0.0.9
# murmurhash                    1.0.3
# music21                       5.5.0
# natsort                       5.5.0
# nbclient                      0.5.1
# nbconvert                     5.6.1
# nbformat                      5.0.8
# nest-asyncio                  1.4.3
# networkx                      2.5
# nibabel                       3.0.2
# nltk                          3.2.5
# notebook                      5.3.1
# np-utils                      0.5.12.1
# numba                         0.48.0
# numexpr                       2.7.1
# numpy                         1.18.5
# nvidia-ml-py3                 7.352.0
# oauth2client                  4.1.3
# oauthlib                      3.1.0
# okgrade                       0.4.3
# opencv-contrib-python         3.4.2.16
# opencv-python                 4.1.2.30
# openpyxl                      2.5.9
# opt-einsum                    3.3.0
# osqp                          0.6.1
# packaging                     20.4
# palettable                    3.3.0
# pandas                        1.1.4
# pandas-datareader             0.9.0
# pandas-gbq                    0.13.3
# pandas-profiling              1.4.1
# pandocfilters                 1.4.3
# panel                         0.9.7
# param                         1.10.0
# parso                         0.7.1
# pathlib                       1.0.1
# patsy                         0.5.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        7.0.0
# pip                           19.3.1
# pip-tools                     4.5.1
# plac                          1.1.3
# plotly                        4.4.1
# plotnine                      0.6.0
# pluggy                        0.7.1
# portpicker                    1.3.1
# prefetch-generator            1.0.1
# preshed                       3.0.2
# prettytable                   1.0.1
# progressbar2                  3.38.0
# prometheus-client             0.8.0
# promise                       2.3
# prompt-toolkit                1.0.18
# protobuf                      3.12.4
# psutil                        5.4.8
# psycopg2                      2.7.6.1
# ptyprocess                    0.6.0
# py                            1.9.0
# pyarrow                       0.14.1
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.2
# pycparser                     2.20
# pyct                          0.4.8
# pydata-google-auth            1.1.0
# pydot                         1.3.0
# pydot-ng                      2.0.0
# pydotplus                     2.0.2
# PyDrive                       1.3.1
# pyemd                         0.5.1
# pyglet                        1.5.0
# Pygments                      2.6.1
# pygobject                     3.26.1
# pymc3                         3.7
# PyMeeus                       0.3.7
# pymongo                       3.11.0
# pymystem3                     0.2.0
# PyOpenGL                      3.1.5
# pyparsing                     2.4.7
# pypng                         0.0.20
# pyrsistent                    0.17.3
# pysndfile                     1.3.8
# PySocks                       1.7.1
# pystan                        2.19.1.1
# pytest                        3.6.4
# python-apt                    1.6.5+ubuntu0.3
# python-chess                  0.23.11
# python-dateutil               2.8.1
# python-louvain                0.14
# python-slugify                4.0.1
# python-utils                  2.4.0
# pytz                          2018.9
# pyviz-comms                   0.7.6
# PyWavelets                    1.1.1
# PyYAML                        3.13
# pyzmq                         19.0.2
# qtconsole                     4.7.7
# QtPy                          1.9.0
# regex                         2019.12.20
# requests                      2.23.0
# requests-oauthlib             1.3.0
# resample2d-cuda               0.0.0
# resampy                       0.2.2
# retrying                      1.3.3
# rpy2                          3.2.7
# rsa                           4.6
# scikit-image                  0.16.2
# scikit-learn                  0.22.2.post1
# scipy                         1.4.1
# screen-resolution-extra       0.0.0
# scs                           2.1.2
# seaborn                       0.11.0
# Send2Trash                    1.5.0
# setproctitle                  1.1.10
# setuptools                    50.3.2
# setuptools-git                1.2
# Shapely                       1.7.1
# simplegeneric                 0.8.1
# six                           1.15.0
# sklearn                       0.0
# sklearn-pandas                1.8.0
# slugify                       0.0.1
# smart-open                    3.0.0
# snowballstemmer               2.0.0
# sortedcontainers              2.2.2
# spacy                         2.2.4
# Sphinx                        1.8.5
# sphinxcontrib-serializinghtml 1.1.4
# sphinxcontrib-websupport      1.2.4
# SQLAlchemy                    1.3.20
# sqlparse                      0.4.1
# srsly                         1.0.2
# statsmodels                   0.10.2
# sympy                         1.1.1
# tables                        3.4.4
# tabulate                      0.8.7
# tblib                         1.7.0
# tensorboard                   2.3.0
# tensorboard-plugin-wit        1.7.0
# tensorboardcolab              0.0.22
# tensorboardX                  2.1
# tensorflow                    2.3.0
# tensorflow-addons             0.8.3
# tensorflow-datasets           4.0.1
# tensorflow-estimator          2.3.0
# tensorflow-gcs-config         2.3.0
# tensorflow-hub                0.10.0
# tensorflow-metadata           0.24.0
# tensorflow-privacy            0.2.2
# tensorflow-probability        0.11.0
# termcolor                     1.1.0
# terminado                     0.9.1
# testpath                      0.4.4
# text-unidecode                1.3
# textblob                      0.15.3
# textgenrnn                    1.4.1
# Theano                        1.0.5
# thinc                         7.4.0
# tifffile                      2020.9.3
# toml                          0.10.2
# toolz                         0.11.1
# torch                         1.4.0+cu100
# torchsummary                  1.5.1
# torchtext                     0.3.1
# torchvision                   0.5.0+cu100
# tornado                       5.1.1
# tqdm                          4.41.1
# traitlets                     4.3.3
# tweepy                        3.6.0
# typeguard                     2.7.1
# typing-extensions             3.7.4.3
# tzlocal                       1.5.1
# umap-learn                    0.4.6
# uritemplate                   3.0.1
# urllib3                       1.24.3
# vega-datasets                 0.8.0
# wasabi                        0.8.0
# wcwidth                       0.2.5
# webencodings                  0.5.1
# Werkzeug                      1.0.1
# wget                          3.2
# wheel                         0.35.1
# widgetsnbextension            3.5.1
# wordcloud                     1.5.0
# wrapt                         1.12.1
# xarray                        0.15.1
# xgboost                       0.90
# xkit                          0.0.0
# xlrd                          1.1.0
# xlwt                          1.3.0
# yellowbrick                   0.9.1
# zict                          2.0.0
# zipp                          3.4.0
